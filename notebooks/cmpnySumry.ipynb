# %%
# import libraries
import pandas as pd
import numpy as np

# %% [markdown]
# # Split Company Summary Data

# %%
# read data and check
dfCmpnySumry = pd.read_stata('../data/cmpnySumry/2001-2019소속회사개요(법인등록번호).dta')
dfCmpnySumry.head()
# Out:
#    공개년월   회계년 기업집단명      소속회사명  대표자         설립일       계열편입일   업종코드  \
# 0  2001  2000    고합  고합정밀화학(주)  민병진  1978/10/11  1999/12/31  D2415
# 1  2001  2000    고합   (주)고합엔프라  김상훈  1988/12/07  1988/12/07  D2415
# 2  2001  2000    고합    (주)서울염직  민병진  1992/01/23  1993/01/02   D174
# 3  2001  2000    고합      (주)고합  최삼길  1966/01/24  2000/03/24   D244
# 4  2001  2000    고합    경일건설(주)  이상복  1971/09/22  1978/04/15  F4512
#
#                 영위업종   종업원수  ...       기업공개일       자산총액       부채총액      자본총액  \
# 0  합성고무 및 플라스틱물질 제조업      0  ...                     16      1,762    -1,746
# 1  합성고무 및 플라스틱물질 제조업      0  ...                      0      2,408    -2,408
# 2        섬유 염색 및 가공업      0  ...                  3,876     70,749   -66,873
# 3           화학섬유 제조업  1,899  ...  1973/08/02  2,438,965  2,968,923  -529,958
# 4          토목시설물 건설업     35  ...                 38,148     20,292    17,856
#
#        자본금        매출액       당기순이익        구분        법인등록번호 year2
# 0    1,000          0          -5  회사정리절차개시  1.748110e+12  2001
# 1    6,150          0         -35  회사정리절차개시  1.101111e+12  2001
# 2    3,300          0     -21,926  회사정리절차개시  1.812110e+12  2001
# 3  214,533  1,254,997  -1,266,782      워크아웃  1.341110e+12  2001
# 4    1,974     16,079       3,006  회사정리절차개시  1.243110e+12  2001
#
# [5 rows x 22 columns]

# %%
len(dfCmpnySumry)
# Out:
# 27190

# %%
dfCmpnySumry.year2.unique()
# Out:
# array([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], dtype=int16)

# %%
dfCmpnySumry.groupby('year2').count()
# Out:
#        공개년월   회계년  기업집단명  소속회사명   대표자   설립일  계열편입일  업종코드  영위업종  종업원수  ...  \
# year2                                                                 ...
# 2001    624   624    624    624   624   624    624   624   624   624  ...
# 2002    704   704    704    704   704   704    704   704   704   704  ...
# 2003    841   841    841    841   841   841    841   841   841   841  ...
# 2004    884   884    884    884   884   884    884   884   884   884  ...
# 2005   1312  1312   1312   1312  1312  1312   1312  1312  1312  1312  ...
# 2006   1117  1117   1117   1117  1117  1117   1117  1117  1117  1117  ...
# 2007   1196  1196   1196   1196  1196  1196   1196  1196  1196  1196  ...
# 2008   1681  1681   1681   1681  1681  1681   1681  1681  1681  1681  ...
# 2009   1137  1137   1137   1137  1137  1137   1137  1137  1137  1137  ...
# 2010   1264  1264   1264   1264  1264  1264   1264  1264  1264  1264  ...
# 2011   1554  1554   1554   1554  1554  1554   1554  1554  1554  1554  ...
# 2012   1832  1832   1832   1832  1832  1832   1832  1832  1832  1832  ...
# 2013   1769  1769   1769   1769  1769  1769   1769  1769  1769  1769  ...
# 2014   1677  1677   1677   1677  1677  1677   1677  1677  1677  1677  ...
# 2015   1696  1696   1696   1696  1696  1696   1696  1696  1696  1696  ...
# 2016   1736  1736   1736   1736  1736  1736   1736  1736  1736  1736  ...
# 2017   1980  1980   1980   1980  1980  1980   1980  1980  1980  1980  ...
# 2018   2083  2083   2083   2083  2083  2083   2083  2083  2083  2083  ...
# 2019   2103  2103   2103   2103  2103  2103   2103  2103  2103  2103  ...
#
#        결산주총일  기업공개일  자산총액  부채총액  자본총액   자본금   매출액  당기순이익    구분  법인등록번호
# year2
# 2001     624    624   624   624   624   624   624    624   624     624
# 2002     704    704   704   704   704   704   704    704   704     704
# 2003     841    841   841   841   841   841   841    841   841     841
# 2004     884    884   884   884   884   884   884    884   884     884
# 2005    1312   1312  1312  1312  1312  1312  1312   1312  1312    1312
# 2006    1117   1117  1117  1117  1117  1117  1117   1117  1117    1117
# 2007    1196   1196  1196  1196  1196  1196  1196   1196  1196    1196
# 2008    1681   1681  1681  1681  1681  1681  1681   1681  1681    1681
# 2009    1137   1137  1137  1137  1137  1137  1137   1137  1137    1137
# 2010    1264   1264  1264  1264  1264  1264  1264   1264  1264    1264
# 2011    1554   1554  1554  1554  1554  1554  1554   1554  1554    1554
# 2012    1832   1832  1832  1832  1832  1832  1832   1832  1832    1832
# 2013    1769   1769  1769  1769  1769  1769  1769   1769  1769    1769
# 2014    1677   1677  1677  1677  1677  1677  1677   1677  1677    1677
# 2015    1696   1696  1696  1696  1696  1696  1696   1696  1696    1696
# 2016    1736   1736  1736  1736  1736  1736  1736   1736  1736    1736
# 2017    1980   1980  1980  1980  1980  1980  1980   1980  1980    1980
# 2018    2083   2083  2083  2083  2083  2083  2083   2083  2083    2083
# 2019    2103   2103  2103  2103  2103  2103  2103   2103  2103    2103
#
# [19 rows x 21 columns]

# %%
dfCmpnySumry.columns
# Out:
# Index(['공개년월', '회계년', '기업집단명', '소속회사명', '대표자', '설립일', '계열편입일', '업종코드', '영위업종',
#        '종업원수', '결산기일', '결산주총일', '기업공개일', '자산총액', '부채총액', '자본총액', '자본금', '매출액',
#        '당기순이익', '구분', '법인등록번호', 'year2'],
#       dtype='object')

# %%
for y in range(2001, 2020):
    df = dfCmpnySumry[dfCmpnySumry['year2'] == y]
    df.to_excel(f"../data/cmpnySumry/cmpnySumry{y}Kor.xlsx", index=False)

# %%
dfCmpnySumry.columns = ['publicYm', 'fisclYr', 'unityGrupNm', 'entrprsNm', 'rprsntvNm', 'fondDe',\
                        'grinil', 'indutyCode', 'indutyNm', 'ordtmEmplyCo', 'stacntDudt', 'beforeBsnsStacntDe',\
                        'entrprsOthbcDe', 'assetsTotamt', 'debtTotamt', 'caplTotamt', 'caplAmount', 'selngAmount', 'thstrmNtpfAmount',\
                        'reconstrctur', 'jurirno', 'year2']

# %%
for y in range(2001, 2020):
    df = dfCmpnySumry[dfCmpnySumry['year2'] == y]
    df.to_excel(f"../data/cmpnySumry/cmpnySumry{y}Eng.xlsx", index=False)

# %% [markdown]
# # Company Summary Data 2021

# %%
dfCmpnySumry21 = pd.read_csv('../data/cmpnySumry/cmpnySumry2021.csv')
dfCmpnySumry21.head()
# Out:
#          법인등록번호          자산총액    직전사업결산일자          자본금액          자본총액  회사구분  \
# 0  1.100000e+12  2.490000e+13  20210323.0  1.410000e+11  9.600000e+12  일반회사
# 1  1.100000e+12  1.190000e+13  20210326.0  4.040000e+11  4.420000e+12  일반회사
# 2  1.100000e+12  6.240000e+11  20210331.0  1.685000e+10  3.520000e+11  일반회사
# 3  1.100000e+12  7.360000e+12  20200325.0  4.900000e+11  3.490000e+12  일반회사
# 4  1.100000e+12  1.630000e+12  20210326.0  1.838800e+10  7.540000e+11  일반회사
#
#            부채총액  소속회사명      기업공개일자     기업설립일  ...                       업종명  \
# 0  1.530000e+13   롯데쇼핑  20060209.0  19700702  ...               소매업; 자동차 제외
# 1  7.450000e+12  지에스건설  19810803.0  19691219  ...                    종합 건설업
# 2  2.720000e+11     삼라         NaN  19690826  ...                    종합 건설업
# 3  3.870000e+12     한화  19760625.0  19521028  ...  화학 물질 및 화학제품 제조업; 의약품 제외
# 4  8.800000e+11   동원산업  19890307.0  19690416  ...                        어업
#
#   상시종업원수    공개년월  출력순위   대표자명           매출액        결산기일         당기순이익  기업집단명  \
# 0  24963  202105  1444    강희태  8.710000e+12  20201231.0 -1.030000e+12     롯데
# 1   6928  202105  2196    임병용  8.890000e+12  20201231.0  3.270000e+11    지에스
# 2     12  202105   276    조유선  1.490000e+11  20201231.0  7.785100e+10     SM
# 3   5026  202105  1053  옥경석 외  4.000000e+12  20191231.0  1.290000e+11     한화
# 4    761  202105  1343    이명우  7.020000e+11  20201231.0  7.895000e+10     동원
#
#    rcmgCode
# 0    620068
# 1    500143
# 2    500429
# 3    350893
# 4    100030
#
# [5 rows x 22 columns]

# %%
dfCmpnySumry21.columns
# Out:
# Index(['법인등록번호', '자산총액', '직전사업결산일자', '자본금액', '자본총액', '회사구분', '부채총액', '소속회사명',
#        '기업공개일자', '기업설립일', '집단편입일', '업종코드', '업종명', '상시종업원수', '공개년월', '출력순위',
#        '대표자명', '매출액', '결산기일', '당기순이익', '기업집단명', 'rcmgCode'],
#       dtype='object')

# %%
dfCmpnySumry21['회계년'] = 2020
dfCmpnySumry21['year2'] = 2021

# %%
dfCmpnySumry21 = dfCmpnySumry21[['공개년월', '회계년', '기업집단명', '소속회사명', '대표자명', '기업설립일',\
                                 '집단편입일', '업종코드', '업종명', '상시종업원수', '결산기일', '직전사업결산일자',\
                                 '기업공개일자', '자산총액', '부채총액', '자본총액', '자본금액', '매출액', '당기순이익',\
                                 '회사구분', '법인등록번호', 'year2', 'rcmgCode']]

# %%
dfCmpnySumry21.to_excel("../data/cmpnySumry/cmpnySumry2020Kor.xlsx", index=False)

# %%
dfCmpnySumry21.columns = ['publicYm', 'fisclYr', 'unityGrupNm', 'entrprsNm', 'rprsntvNm', 'fondDe',\
                          'grinil', 'indutyCode', 'indutyNm', 'ordtmEmplyCo', 'stacntDudt', 'beforeBsnsStacntDe',\
                          'entrprsOthbcDe', 'assetsTotamt', 'debtTotamt', 'caplTotamt', 'caplAmount', 'selngAmount', 'thstrmNtpfAmount',\
                          'reconstrctur', 'jurirno', 'year2', 'rcmgCode']

# %%
dfCmpnySumry21.to_excel("../data/cmpnySumry/cmpnySumry2021Eng.xlsx", index=False)

# %% [markdown]
# # Company Summary Data 2021

# %%
dfCmpnySumry20 = pd.read_csv('../data/cmpnySumry/cmpnySumry2020.csv')
dfCmpnySumry20.head()
# Out:
#      공개년월 기업집단명          소속회사명  대표자         설립일       계열편입일 업종코드  \
# 0  202005    넥슨        (유)가승개발  서춘식  2016/01/21  2016/01/21  R91
# 1  202005   지에스        (유)가승개발  서춘식  2016/01/21  2016/04/01  R91
# 2  202005   카카오   (유)매디슨카운티의다리  이명한  2016/11/16  2020/02/03  R90
# 3  202005   엘에스  (유)빌드윈문경태양광발전  김선철  2018/12/11  2019/02/01  D35
# 4  202005   엘에스  (유)빌드윈인동태양광발전  김선철  2018/12/11  2019/02/01  D35
#
#                      영위업종 종업원수        결산기일  ...    자산총액   부채총액   자본총액  자본금  \
# 0         스포츠 및 오락관련 서비스업    3  2019/12/31  ...  15,208  6,064  9,144  100
# 1         스포츠 및 오락관련 서비스업    3  2019/12/31  ...  15,208  6,064  9,144  100
# 2      창작, 예술 및 여가관련 서비스업    0  2019/12/31  ...      11     28    -17   10
# 3  전기, 가스, 증기 및 공기 조절 공급업    1  2019/12/31  ...     331      0    331  331
# 4  전기, 가스, 증기 및 공기 조절 공급업    1  2019/12/31  ...   4,883  4,140    743  756
#
#    매출액 당기순이익    구분         법인등록번호 kiscode      rcmgCode
# 0    0  -465  일반회사  1345140003989  HM8099  1.802408e+09
# 1  NaN  -465  일반회사  1345140003989  HM8099  1.802408e+09
# 2    3     2  일반회사  1101140192605  HV8949  1.803409e+09
# 3    0     0  일반회사  1754140000582  JJ5268  2.102105e+09
# 4    0   -13  일반회사  1760140002014  JJ5267  2.102105e+09
#
# [5 rows x 22 columns]

# %%
dfCmpnySumry20['회계년'] = 2019
dfCmpnySumry20['year2'] = 2020

# %%
dfCmpnySumry20.columns
# Out:
# Index(['공개년월', '기업집단명', '소속회사명', '대표자', '설립일', '계열편입일', '업종코드', '영위업종', '종업원수',
#        '결산기일', '결산주총일', '기업공개일', '자산총액', '부채총액', '자본총액', '자본금', '매출액', '당기순이익',
#        '구분', '법인등록번호', 'kiscode', 'rcmgCode', '회계년', 'year2'],
#       dtype='object')

# %%
dfCmpnySumry20[dfCmpnySumry20['rcmgCode'].isna()]
# Out:
#         공개년월 기업집단명            소속회사명  대표자         설립일       계열편입일 업종코드  \
# 154   202005   네이버          (주)락스퀘어  조성환  2017/04/28  2018/03/01  J58
# 628   202005    농협       (주)인코단트래이딩  방재일  1998/09/25  2019/07/01  C14
# 1402  202005    삼성  삼성코닝어드밴스드글라스(유)  정지용  2012/04/27  2012/06/01  C23
#
#                         영위업종 종업원수        결산기일  ...     자본총액      자본금      매출액  \
# 154                      출판업   42  2019/12/31  ...   -3,970       34      NaN
# 628   의복, 의복 액세서리 및 모피제품 제조업    0  2019/12/31  ...   -1,966      178    2,221
# 1402            비금속 광물제품 제조업  314  2019/12/31  ...  347,492  430,000  244,202
#
#        당기순이익    구분         법인등록번호 kiscode rcmgCode   회계년  year2
# 154   -3,024  일반회사  1101116389757     NaN      NaN  2019   2020
# 628     -230  일반회사  1101111590333     NaN      NaN  2019   2020
# 1402      68  일반회사  1648140000991     NaN      NaN  2019   2020
#
# [3 rows x 24 columns]

# %%
dfCmpnySumry20.iloc[628, -3]
# Out:
# nan

# %%
dfCmpnySumry20.iloc[628, -3] = 1403403617

# %%
dfCmpnySumry20.iloc[1402, -3]
# Out:
# nan

# %%
dfCmpnySumry20.iloc[1402, -3] = 19010413

# %%
dfCmpnySumry20['rcmgCode'].nunique()
# Out:
# 2273

# %%
len(dfCmpnySumry20)
# Out:
# 2284

# %%
dfCmpnySumry20.columns
# Out:
# Index(['공개년월', '기업집단명', '소속회사명', '대표자', '설립일', '계열편입일', '업종코드', '영위업종', '종업원수',
#        '결산기일', '결산주총일', '기업공개일', '자산총액', '부채총액', '자본총액', '자본금', '매출액', '당기순이익',
#        '구분', '법인등록번호', 'kiscode', 'rcmgCode', '회계년', 'year2'],
#       dtype='object')

# %%
dfCmpnySumry20 = dfCmpnySumry20[['공개년월', '회계년', '기업집단명', '소속회사명', '대표자', '설립일',\
                                 '계열편입일', '업종코드', '영위업종', '종업원수', '결산기일', '결산주총일',\
                                 '기업공개일', '자산총액', '부채총액', '자본총액', '자본금', '매출액', '당기순이익',\
                                 '구분', '법인등록번호', 'year2', 'rcmgCode']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [82], in <module>
# ----> 1 dfCmpnySumry20 = dfCmpnySumry20[['공개년월', '회계년', '기업집단명', '소속회사명', '대표자', '설립일',\
#       2                                  '계열편입일', '업종코드', '영위업종', '종업원수', '결산기일', '결산주총일',\
#       3                                  '기업공개일', '자산총액', '부채총액', '자본총액', '자본금', '매출액', '당기순이익',\
#       4                                  '구분', '법인등록번호', 'year2', 'rcmgCode']]
#
# File ~/opt/anaconda3/envs/dart-manager/lib/python3.8/site-packages/pandas/core/frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File ~/opt/anaconda3/envs/dart-manager/lib/python3.8/site-packages/pandas/core/indexes/base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5782 self._raise_if_missing(keyarr, indexer, axis_name)
#    5784 keyarr = self.take(indexer)
#    5785 if isinstance(key, Index):
#    5786     # GH 42790 - Preserve name from an Index
#
# File ~/opt/anaconda3/envs/dart-manager/lib/python3.8/site-packages/pandas/core/indexes/base.py:5845, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5842     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5844 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5845 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['공개년월', '회계년', '기업집단명', '소속회사명', '대표자', '설립일', '계열편입일', '업종코드', '영위업종', '종업원수', '결산기일', '결산주총일', '기업공개일', '자산총액', '부채총액', '자본총액', '자본금', '매출액', '당기순이익', '구분', '법인등록번호'] not in index"

# %%
dfCmpnySumry20.to_excel("../data/cmpnySumry/cmpnySumry2020Kor.xlsx", index=False)

# %%
dfCmpnySumry20.columns = ['publicYm', 'fisclYr', 'unityGrupNm', 'entrprsNm', 'rprsntvNm', 'fondDe',\
                          'grinil', 'indutyCode', 'indutyNm', 'ordtmEmplyCo', 'stacntDudt', 'beforeBsnsStacntDe',\
                          'entrprsOthbcDe', 'assetsTotamt', 'debtTotamt', 'caplTotamt', 'caplAmount', 'selngAmount', 'thstrmNtpfAmount',\
                          'reconstrctur', 'jurirno', 'year2', 'rcmgCode']

# %%
dfCmpnySumry20.to_excel("../data/cmpnySumry/cmpnySumry2020Eng.xlsx", index=False)
