# %%
import sys
sys.path.append('../scripts')

import requests
import zipfile
import xml.etree.ElementTree as ET
import os
import pickle
from utils import download, clean
from selenium import webdriver
import chromedriver_autoinstaller
import numpy as np
import pandas as pd

# %%
chromedriver_autoinstaller.install(path="../utils/")
# Out:
# '/Users/choidamian/Chaebol/utils/101/chromedriver'

# %% [markdown]
# # Download Company Code File

# %%
class Api:
    
    def __init__(self, apiKey):
        
        self.apiKey = apiKey
        self.corpCode = None

    def getCorpCode(self, path):

        url = "https://opendart.fss.or.kr/api/corpCode.xml?crtfc_key=" + self.apiKey
        download(url, path)

        with zipfile.ZipFile(path, 'r') as zipObj:
            fileList = zipObj.namelist()
            target = fileList[0]
        
        loc = os.path.normpath(path)
        loc = loc.split(os.sep)
        loc = '/'.join(loc[:-1])
        
        with zipfile.ZipFile(path, 'r') as zipRef:
            zipRef.extractall(loc)

        self.corpCode = loc + '/' + target
        print(f'Corporation Code File downloaded to {self.corpCode}')

    def findCorpCode(self, corpNm):
        
        if not self.corpCode:
            print('No corporation code file found. Downloading the code file...')
            self.getCorpCode('../data/raw/opendart/corpCode/CORPCODE.zip')

        xml = ET.parse(self.corpCode)
        root = xml.getroot()

        lists = root.findall('list')

        codeList = []
        for list in lists:
            if (list.find('corp_name').text == corpNm):
                codeList.append(list.find('corp_code').text)
                
        return codeList

    def findCorpCode(self, corpNm):
        
        if not self.corpCode:
            print('No corporation code file found. Downloading the code file...')
            self.getCorpCode('../data/raw/opendart/corpCode/CORPCODE.zip')

        xml = ET.parse(self.corpCode)
        root = xml.getroot()

        lists = root.findall('list')

        codeList = []
        for list in lists:
            if (list.find('corp_name').text == corpNm):
                codeList.append(list.find('corp_code').text)
        return codeList

    def findRceptNum(self, corpNm, year):

        codeList = self.findCorpCode(corpNm)
        pblntfTy = 'j'
        pblntfDetailTy = "J004"
        pgCnt = "50"
        bgnDe = str(year) + '0501'
        endDe = str(year+1) + '0430'

        # find the firm that submitted reports to FTC whose name is <firmname>
        for corpCode in codeList:
            url = "https://opendart.fss.or.kr/api/list.json?corp_code=" + corpCode + "&crtfc_key=" + self.apiKey \
            + "&bgn_de=" + bgnDe + "&end_de=" + endDe + "&last_reprt_at=Y" + "&pblntf_ty=" + pblntfTy + \
            "&pblntf_detail_ty=" + pblntfDetailTy + "&page_count=" + pgCnt
            res = requests.get(url)
            content = res.json()
            if 'list' in content:
                break
        
        else:
            raise ValueError(f"{corpNm}: no report found for {bgnDe} ~ {endDe}")


        # find all the reports whose names contain the string '대규모기업집단현황공시[연1회공시및1/4분기용' and save as a list
        # and return rcept_no of the last report in the list
        receptNums = [report['rcept_no'] for report in content['list'] if ('대규모기업집단현황공시[연1회공시및1/4분기용(대표회사)]' \
                        in report['report_nm'])]
        
        if (corpNm == '교보생명보험' and year == 2019) or (corpNm == '아모레퍼시픽그룹' and year == 2019):
            receptNums = [receptNums[0]]
            print(receptNums[0])
        
        assert len(receptNums) >= 1, f'{corpNm}: no 대규모기업집단현황공시[연1회공시및1/4분기용(대표회사)] found for {bgnDe} ~ {endDe}'
        assert len(receptNums) <= 1, f'{corpNm}: Too many 대규모기업집단현황공시[연1회공시및1/4분기용(대표회사)] report found'

        return receptNums[0]

    def getSharesURL(self, corpNm, year):

        rceptNum = self.findRceptNum(corpNm, year)
        driver = webdriver.Chrome()
        driver.implicitly_wait(3)
        url = "http://dart.fss.or.kr/dsaf001/main.do?rcpNo=" + rceptNum
        driver.get(url)

        # In the navigation menu click the link that contains the string '소유지분현황'
        driver.find_element_by_partial_link_text('소유지분현황').click()

        # get the url of the '소유지분현황' page and return it
        sharesURL = driver.find_element_by_id('ifrm').get_attribute('src')
        
        # quit
        driver.quit()

        return sharesURL

    def getSharesTable(self, corpNm, year):
        
        # get shares url
        url = self.getSharesURL(corpNm, year)
        
        # parse html tables which includes string data '동일인'(the same person in Korean) with thousands delimiter ',' 
        tables = pd.read_html(url, match='동일인', thousands=',')
        
        # convert column names
        for table in tables:
            if len(table.columns) != 12:
                print(table.head())
                
            if len(table.columns) == 11 and corpNm == 'LS' and year == 2019:
                table.insert(0, '금융회사', np.nan)
            elif len(table.columns) == 11 and corpNm == '미래에셋캐피탈' and year == 2019:
                table.insert(4, '금융회사', np.nan)
            elif len(table.columns) == 9 and corpNm == '미래에셋캐피탈' and year == 2019:
                table.insert(4, '금융회사', np.nan)
                table.insert(8, '우선주주식수', np.nan)
                table.insert(9, '우선주지분율', np.nan)
                
            table.columns = ['금융회사', '소속회사명', '동일인과의관계', '동일인과의관계2', '동일인과의관계3', '성명', \
                             '보통주주식수', '보통주지분율', '우선주주식수', '우선주지분율', '합계주식수', '합계지분율']
            
        # concat tables
        df = pd.concat(tables)
        df.reset_index(inplace=True)
        df.drop(columns=['index'], inplace=True)
        df = df[df['소속회사명'] != '소속회사명']

        # save the data in the after_cleansing folder
        if not os.path.exists(f'../data/ownership-status/raw/{year}'):
            os.makedirs(f'../data/ownership-status/raw/{year}')
        df.to_excel(f'../data/ownership-status/raw/{year}/{corpNm}.xlsx', index=False)

        return df

# %%
np.nan
# Out:
# nan

# %%
apiKey = "7946dcde119af7656afc01157071c0ab9488b9ad"
api = Api(apiKey)
api.getSharesTable('삼성전자', 2019)
# Out:
# No corporation code file found. Downloading the code file...
# Corporation Code File downloaded to ../data/raw/opendart/corpCode/CORPCODE.xml
#        금융회사    소속회사명 동일인과의관계       동일인과의관계2       동일인과의관계3   성명     보통주주식수  \
# 0     비금융회사    삼성전자㈜    동일인측            동일인            동일인  이재용   42020150
# 1     비금융회사    삼성전자㈜    동일인측             친족       배우자/혈족1촌  이건희  249273200
# 2     비금융회사    삼성전자㈜    동일인측             친족       배우자/혈족1촌  홍라희   54153600
# 3     비금융회사    삼성전자㈜    동일인측             친족         혈족2~4촌  구지은       4200
# 4     비금융회사    삼성전자㈜    동일인측             친족         혈족5~6촌  이권수     829350
# ...     ...      ...     ...            ...            ...  ...        ...
# 1301   금융회사  삼성벤처투자㈜    동일인측      기타 동일인관련자      기타 동일인관련자    -          -
# 1302   금융회사  삼성벤처투자㈜    동일인측        동일인측 합계        동일인측 합계    -    6000000
# 1303   금융회사  삼성벤처투자㈜    기타주주  동일인측이 아닌 최다주주  동일인측이 아닌 최다주주    -          -
# 1304   금융회사  삼성벤처투자㈜    기타주주             기타             기타    -          -
# 1305   금융회사  삼성벤처투자㈜      총계             총계             총계    -    6000000
#
#       보통주지분율  우선주주식수 우선주지분율      합계주식수   합계지분율
# 0       0.70       -      -   42020150    0.62
# 1       4.18  619900   0.08  249893100    3.68
# 2       0.91       -      -   54153600    0.80
# 3       0.00       -      -       4200    0.00
# 4       0.01       -      -     829350    0.01
# ...      ...     ...    ...        ...     ...
# 1301       -       -      -          -       -
# 1302  100.00       -      -    6000000  100.00
# 1303       -       -      -          -       -
# 1304       -       -      -          -       -
# 1305  100.00       -      -    6000000  100.00
#
# [1306 rows x 12 columns]

# %%
'https://dart.fss.or.kr/report/viewer.do?rcpNo=20200601000086&dcmNo=7361996&eleId=12&offset=1725750&length=732758&dtd=dart3.xsd'

# %%
url = 'https://dart.fss.or.kr/report/viewer.do?rcpNo=20200529001718&dcmNo=7360843&eleId=13&offset=179273&length=278115&dtd=dart3.xsd'
tables = pd.read_html(url, match='동일인', thousands=',')
for table in tables:
    table.columns = ['금융회사', '소속회사명', '동일인과의관계', '동일인과의관계2', '동일인과의관계3', '성명', \
                     '보통주주식수', '보통주지분율', '우선주주식수', '우선주지분율', '합계주식수', '합계지분율']

# %%
with open('../data/utils/dGrpCmpny/dGrpCmpny19.pkl', 'rb') as f:
    dGrpCmpny19 = pickle.load(f)
print(dGrpCmpny19)
# Out:
# {'기업집단': ['삼성', '현대자동차', '에스케이', '엘지', '롯데', '포스코', '한화', '지에스', '현대중공업', '농협', '신세계', '케이티', '씨제이', '한진', '두산', '엘에스', '부영', '대림', '미래에셋', '금호아시아나', '에쓰-오일', '현대백화점', '카카오', '한국투자금융', '교보생명보험', '효성', '하림', '영풍', '대우조선해양', '케이티앤지', '에이치디씨', '케이씨씨', '코오롱', '대우건설', '오씨아이', '이랜드', '태영', 'SM', 'DB', '세아', '네이버', '넥슨', '한국타이어', '호반건설', '셀트리온', '중흥건설', '넷마블', '아모레퍼시픽', '태광', '동원', '한라', '삼천리', '한국지엠', '동국제강', '다우키움', '금호석유화학', '애경', '하이트진로', '유진'], '대표회사': ['삼성전자', '현대자동차', 'SK', 'LG', '롯데지주', '포스코', '한화', 'GS', '한국조선해양', '농협경제지주', '신세계', '케이티', 'CJ', '대한항공', '두산', 'LS', '부영', '대림산업', '미래에셋캐피탈', '금호산업', 'S-Oil', '현대백화점', '카카오', '한국금융지주', '교보생명보험', '효성', '하림지주', '영풍', '대우조선해양', '케이티앤지', 'HDC', '케이씨씨', '코오롱', '대우건설', 'OCI', '이랜드월드', '태영건설', '티케이케미칼', 'DB', '세아홀딩스', 'NAVER', '엔엑스씨', '한국앤컴퍼니', '호반건설', '셀트리온홀딩스', '중흥건설', '넷마블', '아모레퍼시픽그룹', '태광산업', '동원엔터프라이즈', '한라홀딩스', '삼천리', '한국지엠', '동국제강', '키움증권', '금호석유화학', 'AK홀딩스', '하이트진로홀딩스', '유진기업']}

# %%
dGrpCmpny19['grp'] = dGrpCmpny19['기업집단']
dGrpCmpny19['repreCmpny'] = dGrpCmpny19['대표회사']
del dGrpCmpny19['기업집단']
del dGrpCmpny19['대표회사']
print(dGrpCmpny19)
# Out:
# {'grp': ['삼성', '현대자동차', '에스케이', '엘지', '롯데', '포스코', '한화', '지에스', '현대중공업', '농협', '신세계', '케이티', '씨제이', '한진', '두산', '엘에스', '부영', '대림', '미래에셋', '금호아시아나', '에쓰-오일', '현대백화점', '카카오', '한국투자금융', '교보생명보험', '효성', '하림', '영풍', '대우조선해양', '케이티앤지', '에이치디씨', '케이씨씨', '코오롱', '대우건설', '오씨아이', '이랜드', '태영', 'SM', 'DB', '세아', '네이버', '넥슨', '한국타이어', '호반건설', '셀트리온', '중흥건설', '넷마블', '아모레퍼시픽', '태광', '동원', '한라', '삼천리', '한국지엠', '동국제강', '다우키움', '금호석유화학', '애경', '하이트진로', '유진'], 'repreCmpny': ['삼성전자', '현대자동차', 'SK', 'LG', '롯데지주', '포스코', '한화', 'GS', '한국조선해양', '농협경제지주', '신세계', '케이티', 'CJ', '대한항공', '두산', 'LS', '부영', '대림산업', '미래에셋캐피탈', '금호산업', 'S-Oil', '현대백화점', '카카오', '한국금융지주', '교보생명보험', '효성', '하림지주', '영풍', '대우조선해양', '케이티앤지', 'HDC', '케이씨씨', '코오롱', '대우건설', 'OCI', '이랜드월드', '태영건설', '티케이케미칼', 'DB', '세아홀딩스', 'NAVER', '엔엑스씨', '한국앤컴퍼니', '호반건설', '셀트리온홀딩스', '중흥건설', '넷마블', '아모레퍼시픽그룹', '태광산업', '동원엔터프라이즈', '한라홀딩스', '삼천리', '한국지엠', '동국제강', '키움증권', '금호석유화학', 'AK홀딩스', '하이트진로홀딩스', '유진기업']}

# %%
dfAppnGroupSttus19 = pd.read_excel('../data/grpSumry/appnGroupSttus/appnGroupSttus2019.xlsx')
clean(dfAppnGroupSttus19)
dfAppnGroupSttus19['repreCmpny'].replace('에스케이', 'SK', regex=True, inplace=True)
dfAppnGroupSttus19['repreCmpny'].replace('엘지', 'LG', regex=True, inplace=True)
dfAppnGroupSttus19['repreCmpny'].replace('지에스', 'GS', regex=True, inplace=True)
dfAppnGroupSttus19['repreCmpny'].replace('씨제이', 'CJ', regex=True, inplace=True)
dfAppnGroupSttus19['repreCmpny'].replace('엘에스', 'LS', regex=True, inplace=True)
dfAppnGroupSttus19['repreCmpny'].replace('디엘', 'DL', regex=True, inplace=True)
dfAppnGroupSttus19['repreCmpny'].replace('에쓰-오일', 'S-Oil', regex=True, inplace=True)
dfAppnGroupSttus19['repreCmpny'].replace('한국투자금융지주', '한국금융지주', regex=True, inplace=True)
dfAppnGroupSttus19['repreCmpny'].replace('에이치디씨', 'HDC', regex=True, inplace=True)
dfAppnGroupSttus19['repreCmpny'].replace('디비아이엔씨', 'DB', regex=True, inplace=True)
dfAppnGroupSttus19['repreCmpny'].replace('오씨아이', 'OCI', regex=True, inplace=True)
dfAppnGroupSttus19['repreCmpny'].replace('네이버', 'NAVER', regex=True, inplace=True)
dfAppnGroupSttus19['repreCmpny'].replace('에이케이홀딩스', 'AK홀딩스', regex=True, inplace=True)
dfAppnGroupSttus19.head()
# Out:
#   unityGrupNm unityGrupCode smerNm repreCmpny  sumCmpnyCo invstmntLmtt  \
# 0          삼성      K1000032    이재용       삼성전자          62     상호출자제한집단
# 1       현대자동차      K3000027    정몽구      현대자동차          53     상호출자제한집단
# 2        에스케이      K1000050    최태원         SK         111     상호출자제한집단
# 3          엘지      K1000051    구광모         LG          75     상호출자제한집단
# 4          롯데      K1000027    신동빈       롯데지주          95     상호출자제한집단
#
#   entrprsCl
# 0        일반
# 1        일반
# 2        일반
# 3        일반
# 4        일반

# %%
gNonChaebol19 = {'grp': ['포스코', '농협', '케이티', '에쓰-오일', '대우조선해양', '케이티앤지', '대우건설', '한국지엠'],
                 'cmpny': ['포스코홀딩스', '농업협동조합중앙회', '케이티', '에쓰-오일', '대우조선해양', '케이티앤지', '대우건설', '한국지엠']}

# %%
apiKey = "7946dcde119af7656afc01157071c0ab9488b9ad"
api = Api(apiKey)
for cmpny in dfAppnGroupSttus19['repreCmpny'][26:]:
    if cmpny in gNonChaebol19['cmpny']:
        continue
    df = api.getSharesTable(cmpny, 2019)
    print("="* 15 + cmpny + "=" * 15)
    print(df.head())
    print(df.tail())
    print("="* 15 + cmpny + "=" * 15)
# Out:
# No corporation code file found. Downloading the code file...
# Corporation Code File downloaded to ../data/raw/opendart/corpCode/CORPCODE.xml
# 20190621000447
# ===============교보생명보험===============
#    금융회사    소속회사명 동일인과의관계 동일인과의관계2   동일인과의관계3   성명    보통주주식수 보통주지분율 우선주주식수  \
# 0  금융회사  교보생명보험㈜    동일인측      동일인        동일인  신창재  34627370  33.78      -
# 1  금융회사  교보생명보험㈜    동일인측       친족  배우자/ 혈족1촌    -       NaN      -      -
# 2  금융회사  교보생명보험㈜    동일인측       친족  배우자/ 혈족1촌    -       NaN      -      -
# 3  금융회사  교보생명보험㈜    동일인측       친족     혈족2~4촌  신경애   1750010   1.71    NaN
# 4  금융회사  교보생명보험㈜    동일인측       친족     혈족2~4촌  신영애   1449960   1.41    NaN
#
#   우선주지분율     합계주식수  합계지분율
# 0      -  34627370  33.78
# 1      -       NaN      -
# 2      -       NaN      -
# 3    NaN   1750010   1.71
# 4    NaN   1449960   1.41
#       금융회사      소속회사명 동일인과의관계       동일인과의관계2       동일인과의관계3 성명  보통주주식수  \
# 298  비금융회사  케이씨에이서비스㈜    동일인측      기타 동일인관련자      기타 동일인관련자  -       -
# 299  비금융회사  케이씨에이서비스㈜    동일인측        동일인측 합계        동일인측 합계  -  600000
# 300  비금융회사  케이씨에이서비스㈜    기타주주  동일인측이 아닌 최다주주  동일인측이 아닌 최다주주  -       -
# 301  비금융회사  케이씨에이서비스㈜    기타주주             기타             기타  -       -
# 302  비금융회사  케이씨에이서비스㈜     총 계            총 계            총 계  -  600000
#
#      보통주지분율 우선주주식수 우선주지분율   합계주식수   합계지분율
# 298       -      -      -       -       -
# 299  100.00      -      -  600000  100.00
# 300       -      -      -       -       -
# 301       -      -      -       -       -
# 302  100.00      -      -  600000  100.00
# ===============교보생명보험===============
# ===============금호건설===============
#     금융회사  소속회사명 동일인과의관계 동일인과의관계2  동일인과의관계3   성명 보통주주식수 보통주지분율 우선주주식수 우선주지분율  \
# 0  비금융회사  금호산업㈜    동일인측      동일인       동일인  박삼구  10000  0.03%      -    NaN
# 1  비금융회사  금호산업㈜    동일인측       친족  배우자/혈족1촌  NaN      -    NaN      -    NaN
# 2  비금융회사  금호산업㈜    동일인측       친족    혈족2~4촌  NaN      -    NaN      -    NaN
# 3  비금융회사  금호산업㈜    동일인측       친족    혈족5~6촌  NaN      -    NaN      -    NaN
# 4  비금융회사  금호산업㈜    동일인측       친족  인척 4촌 이내  NaN      -    NaN      -    NaN
#
#    합계주식수  합계지분율
# 0  10000  0.03%
# 1      -    NaN
# 2      -    NaN
# 3      -    NaN
# 4      -    NaN
#       금융회사 소속회사명 동일인과의관계       동일인과의관계2       동일인과의관계3   성명 보통주주식수   보통주지분율  \
# 416  비금융회사  케이지㈜    동일인측        동일인측 합계        동일인측 합계  NaN  10000  100.00%
# 417  비금융회사  케이지㈜    기타주주  동일인측이 아닌 최다주주  동일인측이 아닌 최다주주  NaN      -      NaN
# 418  비금융회사  케이지㈜    기타주주             기타             기타  NaN      -      NaN
# 419  비금융회사  케이지㈜     총 계            총 계            총 계  NaN  10000  100.00%
# 420   금융회사     -       -              -              -    -      -        -
#
#     우선주주식수 우선주지분율  합계주식수    합계지분율
# 416      -    NaN  10000  100.00%
# 417      -    NaN      -      NaN
# 418      -    NaN      -      NaN
# 419      -    NaN  10000  100.00%
# 420      -      -      -        -
# ===============금호건설===============
# ===============코오롱===============
#     금융회사 소속회사명 동일인과의관계 동일인과의관계2 동일인과의관계3   성명   보통주주식수 보통주지분율 우선주주식수 우선주지분율  \
# 0  비금융회사  ㈜코오롱    동일인측      동일인      동일인  이웅열  6279798  49.74      -      -
# 1  비금융회사  ㈜코오롱    동일인측       친족   혈족2~4촌  이경숙   122562   0.97      -      -
# 2  비금융회사  ㈜코오롱    동일인측       친족   혈족2~4촌  이상희    60000   0.48    NaN    NaN
# 3  비금융회사  ㈜코오롱    동일인측       친족   혈족2~4촌  이혜숙    91562   0.73      -      -
# 4  비금융회사  ㈜코오롱    동일인측       친족   혈족2~4촌  이경주    91362   0.72      -      -
#
#      합계주식수  합계지분율
# 0  6279798  45.83
# 1   122562   0.89
# 2    60000   0.44
# 3    91562   0.67
# 4    91362   0.67
#       금융회사      소속회사명 동일인과의관계     동일인과의관계2     동일인과의관계3  \
# 217  비금융회사     리베토코리아     총 계          총 계          총 계
# 218   금융회사  코오롱인베스트먼트    동일인측          동일인          동일인
# 219   금융회사  코오롱인베스트먼트    동일인측  계열회사(국내+해외)  계열회사(국내+해외)
# 220   금융회사  코오롱인베스트먼트    동일인측      동일인측 합계      동일인측 합계
# 221   금융회사  코오롱인베스트먼트     총 계          총 계          총 계
#
#                                   성명   보통주주식수  보통주지분율   우선주주식수 우선주지분율  \
# 217                                -  3000000   41.66  4200420  58.34
# 218                              이웅열   400000   12.50        -      -
# 219  KOLON CHINA(HK) COMPANY LIMITED  2800000   87.50        -      -
# 220                                -  3200000  100.00        -      -
# 221                                -  3200000  100.00        -      -
#
#        합계주식수  합계지분율
# 217  7200420  100.0
# 218   400000   12.5
# 219  2800000   87.5
# 220  3200000  100.0
# 221  3200000  100.0
# ===============코오롱===============
# ===============OCI===============
#         금융회사  소속회사명  동일인과의관계 동일인과의관계2   동일인과의관계3   성명  보통주주식수 보통주지분율  우선주주식수  \
# 0  비 금 융 회 사  ㈜디씨알이  동 일 인 측      동일인        동일인  NaN     NaN    NaN     NaN
# 1  비 금 융 회 사  ㈜디씨알이  동 일 인 측      친 족  배우자/ 혈족1촌  NaN     NaN    NaN     NaN
# 2  비 금 융 회 사  ㈜디씨알이  동 일 인 측      친 족  배우자/ 혈족1촌  NaN     NaN    NaN     NaN
# 3  비 금 융 회 사  ㈜디씨알이  동 일 인 측      친 족     혈족2~4촌  NaN     NaN    NaN     NaN
# 4  비 금 융 회 사  ㈜디씨알이  동 일 인 측      친 족     혈족5~6촌  NaN     NaN    NaN     NaN
#
#    우선주지분율  합계주식수 합계지분율
# 0     NaN    NaN   NaN
# 1     NaN    NaN   NaN
# 2     NaN    NaN   NaN
# 3     NaN    NaN   NaN
# 4     NaN    NaN   NaN
#           금융회사     소속회사명  동일인과의관계       동일인과의관계2       동일인과의관계3            성명  \
# 350  비 금 융 회 사  오씨아이 페로㈜  동 일 인 측      기타 동일인관련자      기타 동일인관련자           NaN
# 351  비 금 융 회 사  오씨아이 페로㈜  동 일 인 측        동일인측 합계        동일인측 합계           NaN
# 352  비 금 융 회 사  오씨아이 페로㈜    기타 주주  동일인측이 아닌 최다주주  동일인측이 아닌 최다주주  FHCL Limited
# 353  비 금 융 회 사  오씨아이 페로㈜    기타 주주             기타             기타           NaN
# 354  비 금 융 회 사  오씨아이 페로㈜       총계             총계             총계           NaN
#
#        보통주주식수   보통주지분율  우선주주식수  우선주지분율     합계주식수    합계지분율
# 350       NaN      NaN     NaN     NaN       NaN      NaN
# 351  167166.0   50.00%     NaN     NaN  167166.0   50.00%
# 352  167166.0   50.00%     NaN     NaN  167166.0   50.00%
# 353       NaN      NaN     NaN     NaN       NaN      NaN
# 354  334332.0  100.00%     NaN     NaN  334332.0  100.00%
# ===============OCI===============
# ===============카카오===============
#     금융회사   소속회사명 동일인과의관계 동일인과의관계2  동일인과의관계3   성명    보통주주식수 보통주지분율 우선주주식수  \
# 0  비금융회사  (주)카카오    동일인측      동일인       동일인  김범수  12514461  15.01      -
# 1  비금융회사  (주)카카오    동일인측       친족  배우자/혈족1촌    -         -      -      -
# 2  비금융회사  (주)카카오    동일인측       친족    혈족2~4촌    -         -      -      -
# 3  비금융회사  (주)카카오    동일인측       친족    혈족5~6촌  김진원       634   0.00      -
# 4  비금융회사  (주)카카오    동일인측       친족  인척 4촌 이내  정영재     62220   0.07      -
#
#   우선주지분율     합계주식수  합계지분율
# 0      -  12514461  15.01
# 1      -         -      -
# 2      -         -      -
# 3      -       634   0.00
# 4      -     62220   0.07
#       금융회사     소속회사명 동일인과의관계       동일인과의관계2       동일인과의관계3 성명    보통주주식수  \
# 1101  금융회사  (주)카카오페이    동일인측      기타 동일인관련자      기타 동일인관련자  -         -
# 1102  금융회사  (주)카카오페이    동일인측        동일인측 합계        동일인측 합계  /  11563447
# 1103  금융회사  (주)카카오페이    기타주주  동일인측이 아닌 최다주주  동일인측이 아닌 최다주주  -         -
# 1104  금융회사  (주)카카오페이    기타주주             기타             기타  /   7424151
# 1105  금융회사  (주)카카오페이     총 계            총 계            총 계  /  18987598
#
#       보통주지분율 우선주주식수 우선주지분율     합계주식수   합계지분율
# 1101       -      -      -         -       -
# 1102   60.90      -      -  11563447   60.90
# 1103       -      -      -         -       -
# 1104   39.10      -      -   7424151   39.10
# 1105  100.00      -      -  18987598  100.00
# ===============카카오===============
# ===============HDC===============
#     금융회사     소속회사명 동일인과의관계 동일인과의관계2  동일인과의관계3             성명    보통주주식수  \
# 0  비금융회사  에이치디씨(주)    동일인측      동일인       동일인            정몽규  19740019
# 1  비금융회사  에이치디씨(주)    동일인측       친족  배우자/혈족1촌  Kim Julie Ann      1856
# 2  비금융회사  에이치디씨(주)    동일인측       친족  배우자/혈족1촌            박영자     30034
# 3  비금융회사  에이치디씨(주)    동일인측       친족  배우자/혈족1촌            정준선     60000
# 4  비금융회사  에이치디씨(주)    동일인측       친족  배우자/혈족1촌            정원선     30000
#
#    보통주지분율 우선주주식수 우선주지분율     합계주식수   합계지분율
# 0  33.04%      -      -  19740019  33.04%
# 1   0.00%      -      -      1856   0.00%
# 2   0.05%      -      -     30034   0.05%
# 3   0.10%      -      -     60000   0.10%
# 4   0.05%      -      -     30000   0.05%
#      금융회사         소속회사명 동일인과의관계      동일인과의관계2      동일인과의관계3 성명   보통주주식수  \
# 359  금융회사  에이치디씨자산운용(주)     NaN     기타 동일인관련자     기타 동일인관련자  -        -
# 360  금융회사  에이치디씨자산운용(주)     NaN       동일인측 합계       동일인측 합계  /  2760000
# 361  금융회사  에이치디씨자산운용(주)    기타주주  동일인측이 아닌최다주주  동일인측이 아닌최다주주  -        -
# 362  금융회사  에이치디씨자산운용(주)    기타주주            기타            기타  /   400000
# 363  금융회사  에이치디씨자산운용(주)     총 계           총 계           총 계  /  3160000
#
#      보통주지분율 우선주주식수 우선주지분율    합계주식수   합계지분율
# 359       -      -      -        -       -
# 360  87.34%      -      -  2760000  87.34%
# 361       -      -      -        -       -
# 362  12.66%      -      -   400000  12.66%
# 363    100%      -      -  3160000    100%
# ===============HDC===============
# ===============케이씨씨===============
#     금융회사  소속회사명 동일인과의관계 동일인과의관계2  동일인과의관계3   성명   보통주주식수 보통주지분율 우선주주식수 우선주지분율  \
# 0  비금융회사  ㈜케이씨씨    동일인측      동일인       동일인  정몽진  1933740  18.32      -      -
# 1  비금융회사  ㈜케이씨씨    동일인측       친족  배우자/혈족1촌  정상영   532977   5.05      -      -
# 2  비금융회사  ㈜케이씨씨    동일인측       친족  배우자/혈족1촌  홍은진      597   0.01      -      -
# 3  비금융회사  ㈜케이씨씨    동일인측       친족  배우자/혈족1촌  정재림    25162   0.24      -      -
# 4  비금융회사  ㈜케이씨씨    동일인측       친족  배우자/혈족1촌  정명선    58749   0.56      -      -
#
#      합계주식수  합계지분율
# 0  1933740  18.32
# 1   532977   5.05
# 2      597   0.01
# 3    25162   0.24
# 4    58749   0.56
#      금융회사 소속회사명 동일인과의관계      동일인과의관계2      동일인과의관계3 성명 보통주주식수 보통주지분율 우선주주식수  \
# 246  금융회사     -    동일인측     기타 동일인관련자     기타 동일인관련자  -      -      -      -
# 247  금융회사     -    동일인측       동일인측 합계       동일인측 합계  -      -      -      -
# 248  금융회사     -    기타주주  동일인측이 아닌최다주주  동일인측이 아닌최다주주  -      -      -      -
# 249  금융회사     -    기타주주            기타            기타  -      -      -      -
# 250  금융회사     -     총 계           총 계           총 계  -      -      -      -
#
#     우선주지분율 합계주식수 합계지분율
# 246      -     -     -
# 247      -     -     -
# 248      -     -     -
# 249      -     -     -
# 250      -     -     -
# ===============케이씨씨===============
# ===============티케이케미칼===============
#      금융회사   소속회사명   동일인과의관계  동일인과의관계2  동일인과의관계3   성명 보통주주식수 보통주지분율 우선주주식수  \
# 0  소속 회사명  소속 회사명  동일인과의 관계  동일인과의 관계  동일인과의 관계   성명    보통주    보통주    우선주
# 1  소속 회사명  소속 회사명  동일인과의 관계  동일인과의 관계  동일인과의 관계   성명    주식수    지분율    주식수
# 2   비금융회사  ㈜경남티앤디      동일인측       동일인       동일인  우오현  46289  46.29      -
# 3   비금융회사  ㈜경남티앤디      동일인측        친족  배우자/혈족1촌    -      -      -      -
# 4   비금융회사  ㈜경남티앤디      동일인측        친족  배우자/혈족1촌    -      -      -      -
#
#   우선주지분율  합계주식수  합계지분율
# 0    우선주     합계     합계
# 1    지분율    주식수    지분율
# 2      -  46289  46.29
# 3      -      -      -
# 4      -      -      -
#       금융회사         소속회사명 동일인과의관계       동일인과의관계2       동일인과의관계3 성명  보통주주식수  \
# 1461  금융회사  에스엠에이엠씨투자대부㈜    동일인측      기타 동일인관련자      기타 동일인관련자  -       -
# 1462  금융회사  에스엠에이엠씨투자대부㈜    동일인측      ⑨ 동일인측 합계      ⑨ 동일인측 합계  /  680000
# 1463  금융회사  에스엠에이엠씨투자대부㈜    기타주주  동일인측이 아닌 최다주주  동일인측이 아닌 최다주주  -       -
# 1464  금융회사  에스엠에이엠씨투자대부㈜    기타주주             기타             기타  /   20000
# 1465  금융회사  에스엠에이엠씨투자대부㈜     총 계            총 계            총 계  /  700000
#
#      보통주지분율 우선주주식수 우선주지분율   합계주식수  합계지분율
# 1461      -      -      -       -      -
# 1462  97.14      -      -  680000  97.14
# 1463      -      -      -       -      -
# 1464   2.86      -      -   20000   2.86
# 1465   100%      -      -  700000   100%
# ===============티케이케미칼===============
# ===============중흥건설===============
#     금융회사  소속회사명 동일인과의관계 동일인과의관계2  동일인과의관계3   성명   보통주주식수  보통주지분율 우선주주식수  \
# 0  비금융회사  중흥건설㈜    동일인측      동일인       동일인  정창선  1387469  76.74%    NaN
# 1  비금융회사  중흥건설㈜    동일인측       친족  배우자/혈족1촌  안양임    53155   2.94%    NaN
# 2  비금융회사  중흥건설㈜    동일인측       친족  배우자/혈족1촌  정원주   197795  10.94%    NaN
# 3  비금융회사  중흥건설㈜    동일인측       친족  배우자/혈족1촌  NaN      NaN   0.00%    NaN
# 4  비금융회사  중흥건설㈜    동일인측       친족    혈족2~4촌  NaN      NaN   0.00%    NaN
#
#   우선주지분율    합계주식수   합계지분율
# 0    NaN  1387469  76.74%
# 1    NaN    53155   2.94%
# 2    NaN   197795  10.94%
# 3    NaN        -   0.00%
# 4    NaN        -   0.00%
#       금융회사  소속회사명  동일인과의관계       동일인과의관계2       동일인과의관계3   성명  보통주주식수  \
# 501  비금융회사  세흥건설㈜  동 일 인 측        동일인측 합계        동일인측 합계    /  522200
# 502  비금융회사  세흥건설㈜     기타주주  동일인측이 아닌 최다주주  동일인측이 아닌 최다주주  NaN     NaN
# 503  비금융회사  세흥건설㈜     기타주주             기타             기타    /     NaN
# 504  비금융회사  세흥건설㈜      총 계            총 계            총 계    /  522200
# 505   금융회사    NaN     해당없음           해당없음           해당없음  NaN     NaN
#
#       보통주지분율 우선주주식수 우선주지분율   합계주식수    합계지분율
# 501  100.00%      -     0%  522200  100.00%
# 502      NaN    NaN    NaN     NaN      NaN
# 503    0.00%    NaN    NaN       -    0.00%
# 504  100.00%      -     0%  522200  100.00%
# 505      NaN    NaN    NaN     NaN      NaN
# ===============중흥건설===============
# ===============한국앤컴퍼니===============
#     금융회사         소속회사명   동일인과의관계  동일인과의관계2  동일인과의관계3   성명    보통주주식수  보통주지분율  \
# 0   계열사명          계열사명  동일인과의 관계  동일인과의 관계  동일인과의 관계   성명       보통주     보통주
# 1   계열사명          계열사명  동일인과의 관계  동일인과의 관계  동일인과의 관계   성명       주식수     지분율
# 2  비금융회사  한국테크놀로지그룹(주)      동일인측       동일인       동일인  조양래  21942693  23.59%
# 3  비금융회사  한국테크놀로지그룹(주)      동일인측        친족  배우자/혈족1촌  홍문자      2015   0.00%
# 4  비금융회사  한국테크놀로지그룹(주)      동일인측        친족  배우자/혈족1촌  조현범  17959178  19.31%
#
#   우선주주식수 우선주지분율     합계주식수   합계지분율
# 0    우선주    우선주        합계      합계
# 1    주식수    지분율       주식수     지분율
# 2      -      -  21942693  23.59%
# 3      -      -      2015   0.00%
# 4      -      -  17959178  19.31%
#      금융회사           소속회사명 동일인과의관계 동일인과의관계2  동일인과의관계3       성명  보통주주식수 보통주지분율  \
# 138  금융회사  에프더블유에스투자자문(주)    동일인측       친족  배우자/혈족1촌      조현범  306000    51%
# 139  금융회사  에프더블유에스투자자문(주)    동일인측       친족     친족 합계    친족 합계  306000    51%
# 140  금융회사  에프더블유에스투자자문(주)    동일인측  동일인측 합계   동일인측 합계  동일인측 합계  306000    51%
# 141  금융회사  에프더블유에스투자자문(주)    기타주주       기타        기타        -  294000    49%
# 142  금융회사  에프더블유에스투자자문(주)     총 계      총 계       총 계      총 계  600000   100%
#
#     우선주주식수 우선주지분율   합계주식수 합계지분율
# 138      -      -  306000   51%
# 139      -      -  306000   51%
# 140      -      -  306000   51%
# 141      -      -  294000   49%
# 142      -      -  600000  100%
# ===============한국앤컴퍼니===============
# ===============세아홀딩스===============
#     금융회사     소속회사명 동일인과의관계 동일인과의관계2  동일인과의관계3   성명  보통주주식수 보통주지분율 우선주주식수  \
# 0  비금융회사  (주)세아홀딩스    동일인측      동일인       동일인  이순형  506241  12.66      -
# 1  비금융회사  (주)세아홀딩스    동일인측       친족  배우자/혈족1촌  김혜영   62082   1.55      -
# 2  비금융회사  (주)세아홀딩스    동일인측       친족  배우자/혈족1촌  이주성  717953  17.95      -
# 3  비금융회사  (주)세아홀딩스    동일인측       친족  배우자/혈족1촌  이주현   36971   0.92      -
# 4  비금융회사  (주)세아홀딩스    동일인측       친족    혈족2~4촌  이보형   10000   0.25      -
#
#   우선주지분율   합계주식수  합계지분율
# 0      -  506241  12.66
# 1      -   62082   1.55
# 2      -  717953  17.95
# 3      -   36971   0.92
# 4      -   10000   0.25
#      금융회사          소속회사명 동일인과의관계      동일인과의관계2      동일인과의관계3 성명   보통주주식수  \
# 537  금융회사  (주)에스에스아이케이대부    동일인측     기타 동일인관련자     기타 동일인관련자  -        -
# 538  금융회사  (주)에스에스아이케이대부    동일인측       동일인측 합계       동일인측 합계  /  3030000
# 539  금융회사  (주)에스에스아이케이대부    기타주주  동일인측이 아닌최다주주  동일인측이 아닌최다주주  -        -
# 540  금융회사  (주)에스에스아이케이대부    기타주주            기타            기타  /        -
# 541  금융회사  (주)에스에스아이케이대부     총 계           총 계           총 계  /  3030000
#
#      보통주지분율 우선주주식수 우선주지분율    합계주식수   합계지분율
# 537       -      -      -        -       -
# 538  100.00      -      -  3030000  100.00
# 539       -      -      -        -       -
# 540       -      -      -        -       -
# 541  100.00      -      -  3030000  100.00
# ===============세아홀딩스===============
# ===============태광산업===============
#     금융회사  소속회사명 동일인과의관계 동일인과의관계2 동일인과의관계3   성명    보통주주식수  보통주지분율 우선주주식수  \
# 0  비금융회사  태광산업㈜    동일인측      동일인      동일인  이호진  327333.0   29.40    NaN
# 1  비금융회사  태광산업㈜    동일인측       친족   혈족2~4촌  이동준    9205.0    0.83    NaN
# 2  비금융회사  태광산업㈜    동일인측       친족   혈족2~4촌  이원준   83370.0    7.49    NaN
# 3  비금융회사  태광산업㈜    동일인측       친족   혈족2~4촌  이태준    9267.0    0.83    NaN
# 4  비금융회사  태광산업㈜    동일인측       친족   혈족5~6촌  NaN       NaN     NaN    NaN
#
#   우선주지분율     합계주식수  합계지분율
# 0    NaN  327333.0  29.40
# 1    NaN    9205.0   0.83
# 2    NaN   83370.0   7.49
# 3    NaN    9267.0   0.83
# 4    NaN       NaN    NaN
#      금융회사     소속회사명 동일인과의관계       동일인과의관계2       동일인과의관계3       성명     보통주주식수  \
# 347  금융회사  ㈜예가람저축은행    동일인측           계열회사           계열회사  흥국생명보험㈜   553018.0
# 348  금융회사  ㈜예가람저축은행    동일인측         동일인측합계         동일인측합계      NaN  4409000.0
# 349  금융회사  ㈜예가람저축은행    기타주주  동일인측이 아닌 최다주주  동일인측이 아닌 최다주주      NaN        NaN
# 350  금융회사  ㈜예가람저축은행    기타주주             기타             기타      NaN        NaN
# 351  금융회사  ㈜예가람저축은행      총계             총계             총계      NaN  4409000.0
#
#      보통주지분율 우선주주식수 우선주지분율      합계주식수   합계지분율
# 347   12.54    NaN    NaN   553018.0   12.54
# 348  100.00    NaN    NaN  4409000.0  100.00
# 349     NaN    NaN    NaN        NaN     NaN
# 350     NaN    NaN    NaN        NaN     NaN
# 351  100.00    NaN    NaN  4409000.0  100.00
# ===============태광산업===============
# ===============이랜드월드===============
#     금융회사     소속회사명   동일인과의관계  동일인과의관계2  동일인과의관계3   성명   보통주주식수  보통주지분율 우선주주식수  \
# 0  계열회사명     계열회사명  동일인과의 관계  동일인과의 관계  동일인과의 관계   성명      보통주     보통주    우선주
# 1  계열회사명     계열회사명  동일인과의 관계  동일인과의 관계  동일인과의 관계   성명      주식수     지분율    주식수
# 2  비금융회사  (주)이랜드월드      동일인측       동일인       동일인  박성수  1919027  40.67%      -
# 3  비금융회사  (주)이랜드월드      동일인측        친족  배우자/혈족1촌  곽숙재   380405   8.06%      -
# 4  비금융회사  (주)이랜드월드      동일인측        친족    혈족2~4촌    -        -       -      -
#
#   우선주지분율    합계주식수   합계지분율
# 0    우선주       합계      합계
# 1    지분율      주식수     지분율
# 2      -  1919027  40.67%
# 3      -   380405   8.06%
# 4      -        -       -
#      금융회사  소속회사명 동일인과의관계       동일인과의관계2       동일인과의관계3 성명 보통주주식수   보통주지분율  \
# 411  금융회사  (주)리드    동일인측      기타 동일인관련자      기타 동일인관련자  -      -        -
# 412  금융회사  (주)리드    동일인측        동일인측 합계        동일인측 합계  -  51250  100.00%
# 413  금융회사  (주)리드    기타주주  동일인측이 아닌 최다주주  동일인측이 아닌 최다주주  -      -        -
# 414  금융회사  (주)리드    기타주주             기타             기타  -      -        -
# 415  금융회사  (주)리드      총계             총계             총계  -  51250  100.00%
#
#     우선주주식수 우선주지분율  합계주식수    합계지분율
# 411      -      -      -        -
# 412      -      -  51250  100.00%
# 413      -      -      -        -
# 414      -      -      -        -
# 415      -      -  51250  100.00%
# ===============이랜드월드===============
# ===============셀트리온홀딩스===============
#     금융회사       소속회사명 동일인과의관계 동일인과의관계2  동일인과의관계3   성명  보통주주식수 보통주지분율 우선주주식수  \
# 0  비금융회사  (주)셀트리온홀딩스    동일인측      동일인       동일인  서정진  290980  95.51      -
# 1  비금융회사  (주)셀트리온홀딩스    동일인측       친족  인척 4촌 이내  박준성    1840   0.60      -
# 2  비금융회사  (주)셀트리온홀딩스    동일인측       친족     친족 합계    -    1840   0.60      -
# 3  비금융회사  (주)셀트리온홀딩스    동일인측   등기된 임원    등기된 임원  유헌영    1260   0.41      -
# 4  비금융회사  (주)셀트리온홀딩스    동일인측   등기된 임원    등기된 임원  기우성    1200   0.39      -
#
#   우선주지분율   합계주식수  합계지분율
# 0      -  290980  95.51
# 1      -    1840   0.60
# 2      -    1840   0.60
# 3      -    1260   0.41
# 4      -    1200   0.39
#       금융회사          소속회사명 동일인과의관계      동일인과의관계2      동일인과의관계3            성명  \
# 155  비금융회사  ㈜셀트리온충북대코스메틱스    동일인측  계열회사 (국내+해외)  계열회사 (국내+해외)   (주)셀트리온스킨큐어
# 156  비금융회사  ㈜셀트리온충북대코스메틱스    동일인측       동일인측 합계       동일인측 합계             -
# 157  비금융회사  ㈜셀트리온충북대코스메틱스    기타주주  동일인측이 아닌최다주주  동일인측이 아닌최다주주  충북대학교기술지주(주)
# 158  비금융회사  ㈜셀트리온충북대코스메틱스    기타주주            기타            기타             -
# 159  비금융회사  ㈜셀트리온충북대코스메틱스     총 계           총 계           총 계             -
#
#     보통주주식수  보통주지분율 우선주주식수 우선주지분율  합계주식수   합계지분율
# 155  20000   50.00      -      -  20000   50.00
# 156  20000   50.00      -      -  20000   50.00
# 157  20000   50.00      -      -  20000   50.00
# 158      -       -      -      -      -       -
# 159  40000  100.00      -      -  40000  100.00
# ===============셀트리온홀딩스===============
# ===============DB===============
#     금융회사     소속회사명 동일인과의관계 동일인과의관계2  동일인과의관계3   성명    보통주주식수 보통주지분율 우선주주식수  \
# 0  비금융회사  ㈜DB Inc.    동일인측      동일인       동일인  김준기  22522980  11.20      -
# 1  비금융회사  ㈜DB Inc.    동일인측       친족  배우자/혈족1촌  김정희   2205140   1.10      -
# 2  비금융회사  ㈜DB Inc.    동일인측       친족  배우자/혈족1촌  김남호  33856750  16.83      -
# 3  비금융회사  ㈜DB Inc.    동일인측       친족  배우자/혈족1촌  김주원  18486310   9.19      -
# 4  비금융회사  ㈜DB Inc.    동일인측       친족    혈족2~4촌  김명자    286650   0.14      -
#
#   우선주지분율     합계주식수  합계지분율
# 0      -  22522980  11.20
# 1      -   2205140   1.10
# 2      -  33856750  16.83
# 3      -  18486310   9.19
# 4      -    286650   0.14
#      금융회사   소속회사명 동일인과의관계       동일인과의관계2       동일인과의관계3 성명    보통주주식수  보통주지분율  \
# 365  금융회사  DB캐피탈㈜    동일인측      기타 동일인관련자      기타 동일인관련자  -         -       -
# 366  금융회사  DB캐피탈㈜    동일인측        동일인측 합계        동일인측 합계  -  11202800   90.33
# 367  금융회사  DB캐피탈㈜    기타주주  동일인측이 아닌 최다주주  동일인측이 아닌 최다주주  -         -       -
# 368  금융회사  DB캐피탈㈜    기타주주             기타             기타  -   1200000    9.67
# 369  금융회사  DB캐피탈㈜     총 계            총 계            총 계  -  12402800  100.00
#
#     우선주주식수 우선주지분율     합계주식수   합계지분율
# 365      -      -         -       -
# 366      -      -  11202800   90.33
# 367      -      -         -       -
# 368      -      -   1200000    9.67
# 369      -      -  12402800  100.00
# ===============DB===============
# ===============호반건설===============
#     금융회사    소속회사명 동일인과의관계 동일인과의관계2   동일인과의관계3   성명   보통주주식수  보통주지분율 우선주주식수  \
# 2  비금융회사  (주)호반건설    동일인측      동일인        동일인  김상열   290663  10.51%      -
# 3  비금융회사  (주)호반건설    동일인측       친족  배우자/ 혈족1촌  우현희   299930  10.84%      -
# 4  비금융회사  (주)호반건설    동일인측       친족  배우자/ 혈족1촌  김대헌  1513705  54.73%      -
# 5  비금융회사  (주)호반건설    동일인측       친족  배우자/ 혈족1촌  백채남     9100   0.33%      -
# 6  비금융회사  (주)호반건설    동일인측       친족     혈족2~4촌  김삼영    13000   0.47%      -
#
#   우선주지분율    합계주식수   합계지분율
# 2      -   290663  10.51%
# 3      -   299930  10.84%
# 4      -  1513705  54.73%
# 5      -     9100   0.33%
# 6      -    13000   0.47%
#       금융회사          소속회사명 동일인과의관계      동일인과의관계2      동일인과의관계3       성명  \
# 138  비금융회사        세기상사(주)    기타주주            기타            기타        /
# 139  비금융회사        세기상사(주)     총 계           총 계           총 계        /
# 140   금융회사  (주)코너스톤투자파트너스    동일인측  계열회사 (국내+해외)  계열회사 (국내+해외)  (주)호반건설
# 141   금융회사  (주)코너스톤투자파트너스    동일인측       동일인측 합계       동일인측 합계        /
# 142   금융회사  (주)코너스톤투자파트너스     총 계           총 계           총 계        /
#
#       보통주주식수   보통주지분율 우선주주식수 우선주지분율    합계주식수    합계지분율
# 138   198880   48.79%      -      -   198880   48.79%
# 139   407592  100.00%      -      -   407592  100.00%
# 140  4000000  100.00%      -      -  4000000  100.00%
# 141  4000000  100.00%      -      -  4000000  100.00%
# 142  4000000  100.00%      -      -  4000000  100.00%
# ===============호반건설===============
# ===============NAVER===============
#     금융회사   소속회사명 동일인과의관계 동일인과의관계2  동일인과의관계3   성명   보통주주식수 보통주지분율 우선주주식수  \
# 0  비금융회사  네이버(주)    동일인측      동일인       동일인  이해진  6129725   3.72      -
# 1  비금융회사  네이버(주)    동일인측       친족  배우자/혈족1촌    -        -      -      -
# 2  비금융회사  네이버(주)    동일인측       친족    혈족2~4촌    -        -      -      -
# 3  비금융회사  네이버(주)    동일인측       친족    혈족5~6촌    -        -      -      -
# 4  비금융회사  네이버(주)    동일인측       친족  인척 4촌 이내  이경림      150   0.00      -
#
#   우선주지분율    합계주식수 합계지분율
# 0      -  6129725  3.72
# 1      -        -     -
# 2      -        -     -
# 3      -        -     -
# 4      -      150  0.00
#      금융회사     소속회사명 동일인과의관계      동일인과의관계2      동일인과의관계3 성명    보통주주식수  보통주지분율  \
# 601  금융회사  (주)스프링캠프    동일인측     기타 동일인관련자     기타 동일인관련자  -         -       -
# 602  금융회사  (주)스프링캠프    동일인측       동일인측 합계       동일인측 합계  -  54411765  100.00
# 603  금융회사  (주)스프링캠프    기타주주  동일인측이 아닌최다주주  동일인측이 아닌최다주주  -         -       -
# 604  금융회사  (주)스프링캠프    기타주주            기타            기타  -         -       -
# 605  금융회사  (주)스프링캠프     총 계           총 계           총 계  -  54411765  100.00
#
#     우선주주식수 우선주지분율     합계주식수   합계지분율
# 601      -      -         -       -
# 602      -      -  54411765  100.00
# 603      -      -         -       -
# 604      -      -         -       -
# 605      -      -  54411765  100.00
# ===============NAVER===============
# ===============태영건설===============
#     금융회사    소속회사명 동일인과의관계 동일인과의관계2   동일인과의관계3   성명    보통주주식수 보통주지분율 우선주주식수  \
# 0  비금융회사  (주)태영건설    동일인측      동일인        동일인  윤세영    500000   0.65    NaN
# 1  비금융회사  (주)태영건설    동일인측       친족  배우자/ 혈족1촌  윤석민  20707620  27.10    NaN
# 2  비금융회사  (주)태영건설    동일인측       친족   인척 4촌 이내   변탁     40000   0.05    NaN
# 3  비금융회사  (주)태영건설    동일인측       친족   인척 4촌 이내  이상희   2300000   3.01    NaN
# 4  비금융회사  (주)태영건설    동일인측       친족      친족 합계    /  23047620  30.17    NaN
#
#   우선주지분율     합계주식수  합계지분율
# 0    NaN    500000   0.63
# 1    NaN  20707620  26.23
# 2    NaN     40000   0.05
# 3    NaN   2300000   2.91
# 4    NaN  23047620  29.19
#       금융회사        소속회사명 동일인과의관계 동일인과의관계2 동일인과의관계3           성명       보통주주식수  \
# 229  비금융회사  포천바이오에너지(주)    동일인측     계열회사     계열회사      (주)태영건설      4441927
# 230  비금융회사  포천바이오에너지(주)    동일인측     계열회사     계열회사   (주)티에스케이워터      4267735
# 231  비금융회사  포천바이오에너지(주)    동일인측  동일인측 합계  동일인측 합계          NaN      8709662
# 232  비금융회사  포천바이오에너지(주)     총 계      총 계      총 계          NaN      8709662
# 233   금융회사         금융회사    금융회사     금융회사     금융회사  " 해당사항 없음 "  " 해당사항 없음 "
#
#           보통주지분율       우선주주식수       우선주지분율        합계주식수        합계지분율
# 229        51.00            -            -      4441927        51.00
# 230        49.00            -            -      4267735        49.00
# 231       100.00            -            -      8709662       100.00
# 232       100.00            -            -      8709662       100.00
# 233  " 해당사항 없음 "  " 해당사항 없음 "  " 해당사항 없음 "  " 해당사항 없음 "  " 해당사항 없음 "
# ===============태영건설===============
# ===============엔엑스씨===============
#     금융회사    소속회사명 동일인과의관계 동일인과의관계2  동일인과의관계3   성명   보통주주식수  보통주지분율 우선주주식수  \
# 0  비금융회사  (주)엔엑스씨    동일인측      동일인       동일인  김정주  1963000  67.49%      -
# 1  비금융회사  (주)엔엑스씨    동일인측       친족  배우자/혈족1촌  유정현   856000  29.43%      -
# 2  비금융회사  (주)엔엑스씨    동일인측       친족  배우자/혈족1촌  김정민    19750   0.68%      -
# 3  비금융회사  (주)엔엑스씨    동일인측       친족  배우자/혈족1촌  김정윤    19750   0.68%      -
# 4  비금융회사  (주)엔엑스씨    동일인측       친족     친족 합계    /  2858500  98.28%      -
#
#   우선주지분율    합계주식수   합계지분율
# 0      -  1963000  67.49%
# 1      -   856000  29.43%
# 2      -    19750   0.68%
# 3      -    19750   0.68%
# 4      -  2858500  98.28%
#      금융회사           소속회사명 동일인과의관계 동일인과의관계2 동일인과의관계3       성명    보통주주식수  \
# 73  비금융회사       (주)중앙판교개발    기타주주       기타       기타        /     79590
# 74  비금융회사       (주)중앙판교개발     총 계      총 계      총 계        /  81590627
# 75   금융회사  브이아이피사모주식형펀드일호    동일인측     계열회사     계열회사  (주)엔엑스씨   3450719
# 76   금융회사  브이아이피사모주식형펀드일호    동일인측  동일인측 합계  동일인측 합계        /   3450719
# 77   금융회사  브이아이피사모주식형펀드일호     총 계      총 계      총 계        /   3450719
#
#      보통주지분율 우선주주식수 우선주지분율     합계주식수    합계지분율
# 73    0.10%      -      -     79590    0.10%
# 74  100.00%      -      -  81590627  100.00%
# 75  100.00%      -      -   3450719  100.00%
# 76  100.00%      -      -   3450719  100.00%
# 77  100.00%      -      -   3450719  100.00%
# ===============엔엑스씨===============
# ===============동원엔터프라이즈===============
#     금융회사        소속회사명 동일인과의관계 동일인과의관계2  동일인과의관계3   성명   보통주주식수 보통주지분율 우선주주식수  \
# 0  비금융회사  (주)동원엔터프라이즈    동일인측      동일인       동일인  김재철  2864925  24.50      -
# 1  비금융회사  (주)동원엔터프라이즈    동일인측       친족  배우자/혈족1촌  김남정  7948135  67.98      -
# 2  비금융회사  (주)동원엔터프라이즈    동일인측       친족    혈족2~4촌  김재국   147481   1.26      -
# 3  비금융회사  (주)동원엔터프라이즈    동일인측       친족    혈족2~4촌  김재운    67707   0.58      -
# 4  비금융회사  (주)동원엔터프라이즈    동일인측       친족    혈족2~4촌  김재종    27744   0.24      -
#
#   우선주지분율    합계주식수  합계지분율
# 0      -  2864925  24.50
# 1      -  7948135  67.98
# 2      -   147481   1.26
# 3      -    67707   0.58
# 4      -    27744   0.24
#       금융회사     소속회사명 동일인과의관계      동일인과의관계2      동일인과의관계3       성명   보통주주식수  \
# 114  비금융회사  비아이디씨(주)    동일인측   계열회사(국내+해외)   계열회사(국내+해외)  동원산업(주)  1122800
# 115  비금융회사  비아이디씨(주)    동일인측       동일인측 합계       동일인측 합계        /  1122800
# 116  비금융회사  비아이디씨(주)    기타주주  동일인측이 아닌최다주주  동일인측이 아닌최다주주        -        -
# 117  비금융회사  비아이디씨(주)    기타주주            기타            기타        /  1077200
# 118  비금융회사  비아이디씨(주)     총 계           총 계           총 계        /  2200000
#
#      보통주지분율 우선주주식수 우선주지분율    합계주식수   합계지분율
# 114   51.04      -      -  1122800   51.04
# 115   51.04      -      -  1122800   51.04
# 116       -      -      -        -       -
# 117   48.96      -      -  1077200   48.96
# 118  100.00      -      -  2200000  100.00
# ===============동원엔터프라이즈===============
# ===============한라홀딩스===============
#    금융회사   소속회사명 동일인과의관계 동일인과의관계2  동일인과의관계3   성명   보통주주식수 보통주지분율 우선주주식수 우선주지분율  \
# 0   NaN  ㈜한라홀딩스    동일인측      동일인       동일인  정몽원  2545433  24.31      -      -
# 1   NaN  ㈜한라홀딩스    동일인측       친족  배우자/혈족1촌  홍인화     1389   0.01      -      -
# 2   NaN  ㈜한라홀딩스    동일인측       친족  배우자/혈족1촌  정지연      845   0.01      -      -
# 3   NaN  ㈜한라홀딩스    동일인측       친족  배우자/혈족1촌  정지수     1672   0.02      -      -
# 4   NaN  ㈜한라홀딩스    동일인측       친족     친족 합계    /     3906   0.04      -      -
#
#      합계주식수  합계지분율
# 0  2545433  24.31
# 1     1389   0.01
# 2      845   0.01
# 3     1672   0.02
# 4     3906   0.04
#     금융회사        소속회사명 동일인과의관계       동일인과의관계2       동일인과의관계3     성명    보통주주식수  \
# 75   NaN  만도헬라일렉트로닉스㈜     총 계            총 계            총 계      /   2760000
# 76   NaN       만도브로제㈜    동일인측   계열회사 (국내+해외)   계열회사 (국내+해외)    ㈜만도   7000000
# 77   NaN       만도브로제㈜    동일인측        동일인측 합계        동일인측 합계      /   7000000
# 78   NaN       만도브로제㈜    기타주주  동일인측이 아닌 최다주주  동일인측이 아닌 최다주주  Brose   7000000
# 79   NaN       만도브로제㈜     총 계            총 계            총 계      /  14000000
#
#      보통주지분율 우선주주식수 우선주지분율     합계주식수    합계지분율
# 75  100.00%      -      -   2760000  100.00%
# 76   50.00%      -      -   7000000   50.00%
# 77   50.00%      -      -   7000000   50.00%
# 78   50.00%      -      -   7000000   50.00%
# 79  100.00%      -      -  14000000  100.00%
# ===============한라홀딩스===============
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Input In [81], in <module>
#       4 if cmpny in gNonChaebol19['cmpny']:
#       5     continue
# ----> 6 df = api.getSharesTable(cmpny, 2019)
#       7 print("="* 15 + cmpny + "=" * 15)
#       8 print(df.head())
#
# Input In [79], in Api.getSharesTable(self, corpNm, year)
#     118 def getSharesTable(self, corpNm, year):
#     119
#     120     # get shares url
# --> 121     url = self.getSharesURL(corpNm, year)
#     123     # parse html tables which includes string data '동일인'(the same person in Korean) with thousands delimiter ','
#     124     tables = pd.read_html(url, match='동일인', thousands=',')
#
# Input In [79], in Api.getSharesURL(self, corpNm, year)
#      99 def getSharesURL(self, corpNm, year):
# --> 101     rceptNum = self.findRceptNum(corpNm, year)
#     102     driver = webdriver.Chrome()
#     103     driver.implicitly_wait(3)
#
# Input In [79], in Api.findRceptNum(self, corpNm, year)
#      92     print(receptNums[0])
#      94 assert len(receptNums) >= 1, f'{corpNm}: no 대규모기업집단현황공시[연1회공시및1/4분기용(대표회사)] found for {bgnDe} ~ {endDe}'
# ---> 95 assert len(receptNums) <= 1, f'{corpNm}: Too many 대규모기업집단현황공시[연1회공시및1/4분기용(대표회사)] report found'
#      97 return receptNums[0]
#
# AssertionError: 아모레퍼시픽그룹: Too many 대규모기업집단현황공시[연1회공시및1/4분기용(대표회사)] report found

# %%
df = tables[0]
df.head()
# Out:
#     금융회사  소속회사명 동일인과의관계 동일인과의관계2  동일인과의관계3   성명   보통주주식수 보통주지분율 우선주주식수 우선주지분율  \
# 0  비금융회사  KG케미칼    동일인측      동일인       동일인  곽재선  2230957  17.14      -      -
# 1  비금융회사  KG케미칼    동일인측       친족  배우자/혈족1촌  김영란   111430   0.86      -      -
# 2  비금융회사  KG케미칼    동일인측       친족  배우자/혈족1촌  곽정현   391826   3.01      -      -
# 3  비금융회사  KG케미칼    동일인측       친족  배우자/혈족1촌  곽혜은   225351   1.73      -      -
# 4  비금융회사  KG케미칼    동일인측       친족    혈족2~4촌  최고은     1000   0.01      -      -
#
#      합계주식수  합계지분율
# 0  2230957  17.14
# 1   111430   0.86
# 2   391826   3.01
# 3   225351   1.73
# 4     1000   0.01

# %%
tables[-1].head()
# Out:
#    금융회사  소속회사명 동일인과의관계 동일인과의관계2  동일인과의관계3   성명 보통주주식수  보통주지분율 우선주주식수 우선주지분율  \
# 0  금융회사  스마트인슈    동일인측      동일인       동일인    -      -       -      -      -
# 1  금융회사  스마트인슈    동일인측       친족  배우자/혈족1촌  곽혜은  10000  100.00      -      -
# 2  금융회사  스마트인슈    동일인측       친족  배우자/혈족1촌    -      -       -      -      -
# 3  금융회사  스마트인슈    동일인측       친족    혈족2~4촌    -      -       -      -      -
# 4  금융회사  스마트인슈    동일인측       친족    혈족2~4촌    -      -       -      -      -
#
#    합계주식수   합계지분율
# 0      -       -
# 1  10000  100.00
# 2      -       -
# 3      -       -
# 4      -       -

# %%
df = pd.concat(tables)
df.reset_index(inplace=True)
df.drop(columns=['index'], inplace=True)
df.head()
# Out:
#     금융회사  소속회사명 동일인과의관계 동일인과의관계2  동일인과의관계3   성명   보통주주식수 보통주지분율 우선주주식수 우선주지분율  \
# 0  비금융회사  KG케미칼    동일인측      동일인       동일인  곽재선  2230957  17.14      -      -
# 1  비금융회사  KG케미칼    동일인측       친족  배우자/혈족1촌  김영란   111430   0.86      -      -
# 2  비금융회사  KG케미칼    동일인측       친족  배우자/혈족1촌  곽정현   391826   3.01      -      -
# 3  비금융회사  KG케미칼    동일인측       친족  배우자/혈족1촌  곽혜은   225351   1.73      -      -
# 4  비금융회사  KG케미칼    동일인측       친족    혈족2~4촌  최고은     1000   0.01      -      -
#
#      합계주식수  합계지분율
# 0  2230957  17.14
# 1   111430   0.86
# 2   391826   3.01
# 3   225351   1.73
# 4     1000   0.01

# %%
df.tail()
# Out:
#      금융회사  소속회사명 동일인과의관계      동일인과의관계2      동일인과의관계3 성명 보통주주식수  보통주지분율 우선주주식수  \
# 455  금융회사  스마트인슈    동일인측     기타 동일인관련자     기타 동일인관련자  -      -       -      -
# 456  금융회사  스마트인슈    동일인측       동일인측 합계       동일인측 합계  /  10000  100.00      -
# 457  금융회사  스마트인슈    기타주주  동일인측이 아닌최다주주  동일인측이 아닌최다주주  -      -       -      -
# 458  금융회사  스마트인슈    기타주주            기타            기타  /      -       -      -
# 459  금융회사  스마트인슈     총 계           총 계           총 계  /  10000  100.00      -
#
#     우선주지분율  합계주식수   합계지분율
# 455      -      -       -
# 456      -  10000  100.00
# 457      -      -       -
# 458      -      -       -
# 459      -  10000  100.00

# %%
df.tail()
# Out:
#      소속회사명          동일인과의 관계                               성명      보통주  \
#      소속회사명  소속회사명.1 동일인과의 관계     동일인과의 관계.1     동일인과의 관계.2 성명      주식수
# 1301  금융회사  삼성벤처투자㈜     동일인측      기타 동일인관련자      기타 동일인관련자  -        -
# 1302  금융회사  삼성벤처투자㈜     동일인측        동일인측 합계        동일인측 합계  -  6000000
# 1303  금융회사  삼성벤처투자㈜     기타주주  동일인측이 아닌 최다주주  동일인측이 아닌 최다주주  -        -
# 1304  금융회사  삼성벤처투자㈜     기타주주             기타             기타  -        -
# 1305  금융회사  삼성벤처투자㈜       총계             총계             총계  -  6000000
#
#              우선주           합계
#          지분율 주식수 지분율      주식수     지분율
# 1301       -   -   -        -       -
# 1302  100.00   -   -  6000000  100.00
# 1303       -   -   -        -       -
# 1304       -   -   -        -       -
# 1305  100.00   -   -  6000000  100.00

# %%
  
    def getOwnershipStatusTable(self, firmname, year):
        
        # parse raw html table with designated headers

        sharesUrl = self.getSharesURL(firmname, year)
        if ((firmname == 'KG케미칼') & (year == '2020')):
            tables = pd.read_html(url, header=None)
        else:
            tables = pd.read_html(url, header=[0, 1])
        dfs = tables[1:]  # 소유지분현황 page contains empty table so skip this table

        dropList = []
        for i, df in enumerate(dfs):

            colLen = len(df.columns)
            if (colLen == 12):
                header = ['소속회사명1', '소속회사명2', '동일인과의 관계1', '동일인과의 관계2', '동일인과의 관계3', '성명',
                          '보통주 주식수', '보통주 지분율', '우선주 주식수', '우선주 지분율', '합계 주식수', '합계 지분율']
                df.columns = header

            elif (colLen == 11):
                header = ['소속회사명1', '소속회사명2', '동일인과의 관계1', '동일인과의 관계2', '성명',
                          '보통주 주식수', '보통주 지분율', '우선주 주식수', '우선주 지분율', '합계 주식수', '합계 지분율']
                df.columns = header
                df['동일인과의 관계3'] = df['동일인과의 관계2']
            elif (colLen == 9):
                header = ['소속회사명1', '소속회사명2', '동일인과의 관계1', '동일인과의 관계2', '성명',
                          '보통주 주식수', '보통주 지분율', '합계 주식수', '합계 지분율']
                df.columns = header
                df['동일인과의 관계3'] = df['동일인과의 관계2']
                df['우선주 주식수'] = 0
                df['우선주 지분율'] = 0
            else:
                print(f'Removing a table of invalid size {colLen}...: {firmname} {year}')
                dropList.append(i)

        for i in dropList:
            del dfs[i]


        df = pd.concat(dfs)


        # save the raw data in the raw folder
        if not os.path.exists('./data/raw'):
            os.makedirs('./data/raw')
        df.to_csv(f'./data/raw/{firmname}_{year}_raw.csv')

        # 동일한 행이 반복되는 경우 제외
        df.drop_duplicates()

        # '성명' 변수에 '해당사항 없음'이 기재되어 있는 경우 제외
        dropList = list(df[df['성명'].str.contains('해당사항\s+없음', na=False)].index)
        df.drop(dropList, axis=0, inplace=True)

        # (주)나 ㈜를 데이터셋에서 제거
        df.replace('\(주\)', '', regex=True, inplace=True)
        df.replace('㈜', '', regex=True, inplace=True)

        # LS(LS)2019 data cleansing
        if (((firmname == 'LS') & (year == '2019')) | ((firmname == 'LS') & (year == '2020'))):
            mask = df['소속회사명1'] == '엘에스글로벌인코퍼레이티드'
            df[mask] = df[mask].shift(1, axis=1)
            df.loc[mask, '합계 주식수'] = df.loc[mask, '보통주 지분율']

        # 합계 주식수에 숫자가 아닌 다른 문자가 입력되어 있는 경우 제거
        # 신세계(신세계)2019의 에스에스지닷컴은 0.8주의 자기주식을 보유함.
        if ((firmname == '신세계') & (year == '2019')):
            df['합계 주식수'].replace('[^0-9.]*', '', regex=True, inplace=True)
        else:
            df['합계 주식수'].replace('[^0-9]*', '', regex=True, inplace=True)


        # 동일인과의 관계2, 3에 ① - ⑨이 포함되어 있으면(+좌우로 공백이 있는 경우 포함) 제거

        df['동일인과의 관계3'].replace(' *[\u2460-\u2468] *', '', regex=True, inplace=True)
        df['동일인과의 관계2'].replace(' *[\u2460-\u2468] *', '', regex=True, inplace=True)

        # 동원(동원엔터프라이즈)2019 data cleansing
        # 부산신항다목적터미널의 경우 기타에 기타총계 50%가 추가로 입력됨
        if ((firmname == '동원엔터프라이즈') & (year == '2019')):
            df.drop([107], axis=0, inplace=True)

        # 미래에셋(미래에셋캐피탈)2020 data cleansing
        if ((firmname == '미래에셋캐피탈') & (year == '2020')):
            Dapi.copyOrdinaryShares(df, '수원학교사랑', '덕동종합건설')
            Dapi.copyOrdinaryShares(df, '수원학교사랑', '에이치디에스자산관리')
            Dapi.copyOrdinaryShares(df, '수원학교사랑', '영동건설')
            Dapi.copyOrdinaryShares(df, '수원학교사랑', '한동건설')

        # 케이티(케이티)2019, 2020 data cleansing
        if (firmname == '케이티'):
            mask = df['동일인과의 관계3'] == '케이티'
            df.loc[mask, '동일인과의 관계3'] = '동일인'


        # 애경(AK홀딩스)2019 data cleansing
        if ((firmname == 'AK홀딩스') & (year == '2019')):
            # 에이케이스앤에디 합계 주식수와 합계 지분율이 잘못 입력되어 있음: 보통주 자료를 이용하여 채우기
            df.loc[[354, 355, 356, 357], ['합계 주식수', '합계 지분율']] = df.loc[
                [354, 355, 356, 357], ['보통주 주식수', '보통주 지분율']]

            # 퍼시픽제3호전문사모부동산투자유한회사 합계 주식수가 미입력: 보통주 주식수 자료를 이용하여 합계 주식수 채우기
            df.loc[[330], '보통주 주식수'] = int(df.loc[324, '보통주 주식수']) + int(df.loc[329, '보통주 주식수'])
            df.loc[[324, 327, 329, 330], '합계 주식수'] = df.loc[[324, 327, 329, 330], '보통주 주식수']

            # 평택역사 기타주주에 성명이 '합계'인 행이 있음: 필요한 정보가 아니므로 제외
            drop_list2 = list(df[df['성명'].str.contains('합계', na=False)].index)
            df.drop(drop_list2, axis=0, inplace=True)

        # 씨제이(CJ)2019 data cleansing
        # 엠엠오엔터테인먼트 기타에 합계 주식수가 잘못 입력됨: 제거
        if ((firmname == 'CJ') & (year == '2019')):
            # print(df[(df['소속회사명2'] == '엠엠오엔터테인먼트') & (df['동일인과의 관계3'] == '총계')].index)
            id = int(list(df[(df['소속회사명2'] == '엠엠오엔터테인먼트') & (df['동일인과의 관계3'] == '총계')].index)[0]) - 1
            df.drop([id], axis=0, inplace=True)

        # 한진(대한항공)2019 data cleansing
        # 더블유에이씨항공서비스 기타에 합계 주식수가 잘못 입력됨
        if ((firmname == '대한항공') & (year == '2019')):
            # print(df[(df['소속회사명2'] == '엠엠오엔터테인먼트') & (df['동일인과의 관계3'] == '총계')].index)
            id = list(df[(df['소속회사명2'] == '더블유에이씨항공서비스') & (df['동일인과의 관계3'] == '기타')].index)[0]

            id2 = list(df[(df['소속회사명2'] == '더블유에이씨항공서비스') & (df['동일인과의 관계3'] == '총 계')].index)[0]

            df.at[id2, '합계 주식수'] = df.at[id, '합계 주식수']
            df.at[id, '합계 주식수'] = '0'


        # SK2019
        # 디디아이에스씨57 위탁관리부동산투자회사 총계가 1/10

        # 애경(AK홀딩스)2020 data cleansing
        if ((firmname == 'AK홀딩스') & (year == '2020')):

            # 퍼시픽제3호전문사모부동산투자유한회사 합계 주식수가 미입력: 보통주 주식수 자료를 이용하여 합계 주식수 채우기
            df.loc[[309], '보통주 주식수'] = int(df.loc[303, '보통주 주식수']) + int(df.loc[308, '보통주 주식수'])
            df.loc[[303, 306, 308, 309], '합계 주식수'] = df.loc[[303, 306, 308, 309], '보통주 주식수']

            # 평택역사 기타주주에 성명이 '합계'인 행이 있음: 필요한 정보가 아니므로 제외
            drop_list2 = list(df[df['성명'].str.contains('합계', na=False)].index)
            df.drop(drop_list2, axis=0, inplace=True)



        # 한국타이어(한국앤컴퍼니)2019, 2020 data cleansing
        # 두원홀딩스 자료가 중복 입력됨: 제거
        if ((firmname == '한국앤컴퍼니') & (year == '2020')):
            df.drop([116, 117, 118, 119], axis=0, inplace=True)

        # 신세계(신세계)2019, data cleansing
        if ((firmname == '신세계') & (year == '2019')):

            # 신세계 친족 합계 합계 주식수에 동일인 합계 주식수가 포함됨: 제거
            for firm in ('신세계',):
                mask = (df['소속회사명2'] == firm) & (df['동일인과의 관계3'] == '친족 합계')
                mask2 = (df['소속회사명2'] == firm) & (df['동일인과의 관계3'] == '동일인')
                val = int(df.loc[mask, '합계 주식수'])
                val2 = int(df.loc[mask2, '합계 주식수'])
                df.loc[mask, '합계 주식수'] = val - val2
            # 신세계디에프글로벌 기타 동일인관련자 항목에 합계 주식수가 중복되어 입력됨: 제거
            mask = (df['소속회사명2'] == '신세계디에프글로벌') & (df['동일인과의 관계3'] == '기타 동일인관련자')
            df.loc[mask, '합계 주식수'] = '0'

        # 한국앤컴퍼니 친족 합계에 동일인이 포함됨: 제외
        if (((firmname == '한국앤컴퍼니') & (year == '2020')) | ((firmname == '한국앤컴퍼니') & (year == '2019'))):
            for firm in ('한국테크놀로지그룹', '한국타이어앤테크놀로지', '신양월드레저'):
                mask = (df['소속회사명2'] == firm) & (df['동일인과의 관계3'] == '친족 합계')
                mask2 = (df['소속회사명2'] == firm) & (df['동일인과의 관계3'] == '동일인')
                val = int(df.loc[mask, '합계 주식수'])
                val2 = int(df.loc[mask2, '합계 주식수'])
                df.loc[mask, '합계 주식수'] = val - val2

        # 태광(태광산업)2019, 2020 data cleansing
        if (((firmname == '태광산업') & (year == '2020'))):
            # 태광산업 기타 합계 주식수에 총계 합계 주식수가 입력되어 있음: 기타 합계 주식수를 계산하여 변경
            df.loc[22, '합계 주식수'] = int(df.loc[23, '합계 주식수']) - int(df.loc[19, '합계 주식수'])
            df.drop([136], axis=0, inplace=True)

            # 티시스 친족 합계에 동일인이 포함됨: 제외
            mask = (df['소속회사명2'] == '티시스') & (df['동일인과의 관계3'] == '친족 합계')
            mask2 = (df['소속회사명2'] == '티시스') & (df['동일인과의 관계3'] == '동일인')
            val = int(df.loc[mask, '합계 주식수'])
            val2 = int(df.loc[mask2, '합계 주식수'])
            df.loc[mask, '합계 주식수'] = val - val2

        if (((firmname == '키움증권') & (year == '2019'))):
            df.loc[166, '합계 주식수'] = '50000000'


        if (((firmname == '태광산업') & (year == '2019'))):
            mask = (df['소속회사명2'] == '한국케이블텔레콤') & (df['동일인과의 관계3'] == '기타')
            mask2 = (df['소속회사명2'] == '한국케이블텔레콤') & (df['동일인과의 관계3'] == '동일인측이 아닌 최다주주')
            val = int(df.loc[mask, '합계 주식수'])
            val2 = int(df.loc[mask2, '합계 주식수'])
            df.loc[mask, '합계 주식수'] = val - val2

        if (((firmname == '티케이케미칼') & (year == '2020'))):
            mask = (df['소속회사명2'] == '삼환기업') & (df['동일인과의 관계3'] == '친족 합계')
            mask2 = (df['소속회사명2'] == '삼환기업') & (df['동일인과의 관계3'] == '동일인')
            val = int(df.loc[mask, '합계 주식수'])
            val2 = int(df.loc[mask2, '합계 주식수'])
            df.loc[mask, '합계 주식수'] = val - val2

        #카카오 2020
        if ((firmname == '카카오') & (year == '2020')):
            Dapi.subtractOwner(df, "카카오")
        # 신세계2020
        if ((firmname == '신세계') & (year == '2020')):
            Dapi.subtractOwner(df, "신세계")

        # 티케이케미칼2019
        if ((firmname == '티케이케미칼') & (year == '2019')):
            Dapi.subtractOwner(df, "경남티앤디")

        # 중흥건설(중흥건설)2019, 2020 data cleansing
        # shift data by 1 period
        if ((firmname == '중흥건설') & (year == '2020')):
            df.iloc[428, 4:] = df.iloc[428, 4:].shift(1)
            df.loc[428, '동일인과의 관계2'] = '계열회사'
            df.loc[428, '동일인과의 관계3'] = '계열회사'
        elif ((firmname == '중흥건설') & (year == '2019')):
            df.iloc[500, 4:] = df.iloc[500, 4:].shift(1)
            df.loc[500, '동일인과의 관계2'] = '계열회사'
            df.loc[500, '동일인과의 관계3'] = '계열회사'

        # 삼양(삼양홀딩스)2020 data cleansing
        if ((firmname == '삼양홀딩스') & (year == '2020')):
            mask = (df['소속회사명2'] == '삼양에프앤비') & (df['동일인과의 관계3'] == '기타')
            df.loc[mask, '합계 주식수'] = 0

        # 유진(유진기업)2020 data cleansing
        # 천안기업의 경우 친족합계의 합계주식수가 잘못 입력됨
        if ((firmname == '유진기업') & (year == '2020')):
            mask = (df['소속회사명2'] == '천안기업') & (df['동일인과의 관계3'] == '친족 합계')
            mask2 = (df['소속회사명2'] == '천안기업') & (df['동일인과의 관계3'] == '동일인')
            val = int(df.loc[mask, '합계 주식수'])
            val2 = int(df.loc[mask2, '합계 주식수'])
            df.loc[mask, '합계 주식수'] = 123957


        # IMM(아이엠엠인베스트먼트)2020 페트라7의알파 사모투자합자회사 합계 지분율이 100이 안됨.
        # 한국투자금융(한국금융지주)한국투자혁신성장스케일업사모투자합자회사는 2020년 6월 출자 예정임

        # 태영(태영건설)2019 data cleansing
        if ((firmname == '태영건설') & (year == '2019')):
            # 디엠씨미디어 기타 합계 주식수 중복 입력: 제거
            mask = (df['소속회사명2'] == '디엠씨미디어') & (df['동일인과의 관계3'] == '기타')
            df.loc[mask, '합계 주식수'] = '0'
            # 유니시티 합계 주식수, 지분율 미입력
            mask = (df['소속회사명2'] == '유니시티') & (df['동일인과의 관계3'] == '기타')
            df.loc[mask, '합계 주식수'] = df.loc[mask, '보통주 주식수']
            # print(df.loc[mask, '합계 주식수'])

        # 태영(태영건설)2020 data cleansing
        if ((firmname == '태영건설') & (year == '2020')):

            # 유니시티 합계 주식수, 지분율 미입력
            mask = (df['소속회사명2'] == '유니시티') & (df['동일인과의 관계3'] == '기타')
            df.loc[mask, '합계 주식수'] = df.loc[mask, '보통주 주식수']
            # print(df.loc[mask, '합계 주식수'])

        # 롯데(롯데지주)2020 data cleansing
        if (firmname == '롯데지주'):

            # 롯데(롯데지주)2020 raw data의 경우 동일인과의 관계3이 missing value인 경우가 많음: 동일인과의 관계2를 이용하여 채우기
            import pandas as pd

            mask = df['동일인과의 관계1'].str.contains('합계', na=False)
            df.loc[mask, '동일인과의 관계1'] = '합계'
            df.loc[mask, '동일인과의 관계2'] = '합계'
            df.loc[mask, '동일인과의 관계3'] = '합계'

            df['동일인과의 관계2'].astype(str)

            mask = df['동일인과의 관계2'].isnull()
            # print(mask.head(30))
            df.loc[mask, '동일인과의 관계2'] = df.loc[mask, '동일인과의 관계1']

            df['동일인과의 관계3'].astype(str)

            mask = df['동일인과의 관계3'].isnull()
            # print(mask.head(30))
            df.loc[mask, '동일인과의 관계3'] = df.loc[mask, '동일인과의 관계2']


        # LG 2019 동일인측 인물의 동일인과의 관계가 불분명함: '기타 동일인관련자'로 입력
        if ((firmname=="LG") & (year=='2019')):

            mask = df['동일인과의 관계3'].isnull()
            df.loc[mask, '동일인과의 관계3'] = '기타 동일인관련자'




        # 넥슨(엔엑스씨) data cleansing
        if (firmname == '엔엑스씨'):

            # 엔엑스씨 친족 합계에 동일인이 포함됨: 제외
            mask = (df['소속회사명2'] == '엔엑스씨') & (df['동일인과의 관계3'] == '친족 합계')
            mask2 = (df['소속회사명2'] == '엔엑스씨') & (df['동일인과의 관계3'] == '동일인')
            val = int(df.loc[mask, '합계 주식수'])
            val2 = int(df.loc[mask2, '합계 주식수'])
            df.loc[mask, '합계 주식수'] = val - val2

        # 한화2020
        if ((firmname == '한화') & (year == '2020')):
            Dapi.copyOrdinaryShares(df, "일산씨월드", "한화건설")

        # SK2020
        if ((firmname == 'SK') & (year == '2020')):
            mask = (df['소속회사명2'] == '드림어스컴퍼니(舊 아이리버)') & (df['동일인과의 관계3'] == '기타')
            df.loc[mask, '합계 주식수'] = df.loc[mask, '보통주 주식수']
            Dapi.sumShares(df, "유베이스매뉴팩처링아시아")

        # 포스코2020
        if ((firmname == '포스코') & (year == '2020')):
            Dapi.copyOrdinaryShares2(df, "포스코에스피에스")

        if ((df['합계 주식수'].dtype == 'float64') | (df['합계 주식수'].dtype == 'int64')):
            pass
        else:
            # fill missing value and with zero or np.nan and convert the dtype of '합계 주식수' column to int
            df.fillna('0')
            df.replace('^\s*$', np.nan, regex=True, inplace=True)
            df['합계 주식수'] = df['합계 주식수'].astype(float)

        # SK2019
        # 디디아이에스씨57 위탁관리부동산투자회사 총계가 1/10: *10
        if ((firmname == 'SK') & (year == '2019')):
            mask = (df['소속회사명2'] == '디디아이에스씨57 위탁관리부동산투자회사') & (df['동일인과의 관계3'] == '총계')
            df.loc[mask, '합계 주식수'] *= 10

        # 에스케이루브리컨츠 합계 주식수 총계가 미입력: 입력
            Dapi.copySumShares(df, '에스케이루브리컨츠', '계열회사 (국내+해외)')

        # 에스케이에어가스 합계 주식수가 미입력: 입력
            mask = (df['소속회사명2'] == '에스케이에어가스') & (df['동일인과의 관계3'] == '총계')
            df.loc[mask, '합계 주식수'] = float(df.loc[mask, '보통주 주식수'])
            mask2 = (df['소속회사명2'] == '에스케이에어가스') & (df['동일인과의 관계3'] == '계열회사 (국내+해외)')
            df.loc[mask2, '합계 주식수'] = float(df.loc[mask2, '보통주 주식수'])

        # 에스케이트리켐 합계 주식수 총계가 미입력: 입력
            mask = (df['소속회사명2'] == '에스케이트리켐') & (df['동일인과의 관계3'] == '총계')
            mask2 = (df['소속회사명2'] == '에스케이트리켐') & (df['동일인과의 관계3'] == '계열회사 (국내+해외)')
            mask3 = (df['소속회사명2'] == '에스케이트리켐') & (df['동일인과의 관계3'] == '동일인측이 아닌 최대주주')
            df.loc[mask, '합계 주식수'] = float(df.loc[mask2, '합계 주식수']) + float(df.loc[mask3, '합계 주식수'])

        # 에스케이하이닉스 시스템아이씨 총계가 기타에 입력
            mask = (df['소속회사명2'] == '에스케이하이닉스 시스템아이씨') & (df['동일인과의 관계3'] == '총계')
            mask2 = (df['소속회사명2'] == '에스케이하이닉스 시스템아이씨') & (df['동일인과의 관계3'] == '기타')
            df.loc[mask, '합계 주식수'] = float(df.loc[mask2, '합계 주식수'])
            df.loc[mask2, '합계 주식수'] = 0



        # 유베이스매뉴팩처링아시아 합계 주식수 총계가 미입력: 입력
            mask = (df['소속회사명2'] == '유베이스매뉴팩처링아시아') & (df['동일인과의 관계3'] == '총계')
            mask2 = (df['소속회사명2'] == '유베이스매뉴팩처링아시아') & (df['동일인과의 관계3'] == '계열회사 (국내+해외)')
            mask3 = (df['소속회사명2'] == '유베이스매뉴팩처링아시아') & (df['동일인과의 관계3'] == '기타')
            df.loc[mask, '합계 주식수'] = float(df.loc[mask2, '합계 주식수']) + float(df.loc[mask3, '합계 주식수'])

        # 카카오2019
        if ((firmname == '카카오') & (year == '2019')):
            Dapi.sumShares(df, "카카오키즈")

        if ((firmname == 'SK') & (year == '2020')):
            Dapi.sumShares(df, "유베이스매뉴팩처링아시아")

        if ((firmname == 'KG케미칼') & (year == '2020')):
            Dapi.subtractOwner(df, 'KG이니시스')


        # save the data in the after_cleansing folder
        if not os.path.exists('./data/after_cleansing'):
            os.makedirs('./data/after_cleansing')
        df.to_csv(f'./data/after_cleansing/{firmname}_{year}_after_cleansing.csv')

        return df



    def parseCBTable(self, df, firmname, year):

        import numpy as np
        import pandas as pd
        import os

        # extract, make, merge, and calculate

        sum_check =df.groupby('소속회사명2')['동일인과의 관계1'].apply(lambda x: ((x == '총계') | (x == '총 계') | (x == '합계')).sum()).reset_index(name='count')



        sum = df[(df['동일인과의 관계1'].str.contains('총\s*계', regex=True) | df['동일인과의 관계1'].str.contains(
            '합계'))]  # extract rows whose value for '동일인과의 관계1' is '총계'
        sum_reduced = pd.DataFrame(
            {'소속회사명2': sum['소속회사명2'], 'divisor': sum['합계 주식수']})  # make a new df with only '소속회사명2' and '합계 주식수'
        df = pd.merge(df, sum_reduced)  # merge with the original dataset
        df['shares'] = df['합계 주식수'] / df['divisor']  # calculate 'shares' column

        # save the data in the after_sum folder
        if not os.path.exists('./data/after_sum'):
            os.makedirs('./data/after_sum')
        df.to_csv(f'./data/after_sum/{firmname}_{year}_after_sum.csv')

        # make 'type' and 'type2' variable
        # categorize '동일인과의 관계3' column if it exists.
        if ('동일인과의 관계3' in df):
            df['type'] = df['동일인과의 관계3']
            df['type2'] = df['동일인과의 관계3']

            df['type'] = df['type'].apply(Dapi.rel3_categorize)
            df['type2'] = df['type2'].apply(Dapi.rel3_categorize2)

        # Else cat '동일인과의 관계2' column.
        elif ('동일인과의 관계2' in df):
            df['type'] = df['동일인과의 관계2']
            df['type2'] = df['동일인과의 관계2']
            df['type'] = df['type'].apply(Dapi.rel2_categorize)
            df['type2'] = df['type2'].apply(Dapi.rel2_categorize2)

        # save the data in the after_cat folder
        if not os.path.exists('./data/after_cat'):
            os.makedirs('./data/after_cat')
        df.to_csv(f'./data/after_cat/{firmname}_{year}_after_cat.csv')

        # calc values 'own', 'own2', and 'ownername' variable
        own = df.groupby(['소속회사명2', 'type'])['shares'].sum().rename('own').reset_index()
        df = pd.merge(df, own, how='left')

        own2 = df.groupby(['소속회사명2', 'type2'])['shares'].sum().rename('own2').reset_index()
        df = pd.merge(df, own2, how='left')

        for i in df.index:
            val = df.loc[i, 'type']
            if (val == '1'):
                df.loc[i, 'own'] = df.loc[i, 'shares']
            elif (val == '-1'):
                df.loc[i, 'own'] = df.loc[i, 'shares']
            elif (val == '50'):
                df.loc[i, 'own'] = np.nan
            elif (val == '-1'):
                df.loc[i, 'own'] = df.loc[i, 'shares']
            elif (val == '-2'):
                df.loc[i, 'own'] = df.loc[i, 'shares']

        for i in df.index:
            val = df.loc[i, 'type2']
            if (val == '1'):
                df.loc[i, 'own2'] = df.loc[i, 'shares']
            elif (val == '-1'):
                df.loc[i, 'own2'] = df.loc[i, 'shares']
            elif (val == '50'):
                df.loc[i, 'own2'] = np.nan
            elif (val == '-1'):
                df.loc[i, 'own2'] = df.loc[i, 'shares']
            elif (val == '-2'):
                df.loc[i, 'own2'] = df.loc[i, 'shares']

        df['ownername'] = ''

        for i in df.index:
            val = df.loc[i, 'type2']
            if (val == '1'):
                df.loc[i, 'ownername'] = df.loc[i, '성명']

        # save the data in the after_ownername folder
        if not os.path.exists('./data/after_ownername'):
            os.makedirs('./data/after_ownername')
        df.to_csv(f'./data/after_ownername/{firmname}_{year}_after_ownername.csv')

        # discard unwanted rows
        discard = []
        appeared0 = False
        appeared99 = False
        for i in df.index:
            # print(i)
            if (i == 0):
                appeared0 = False
                appeared99 = False
            elif ((i > 0) & (df.loc[i, '소속회사명2'] != df.loc[i - 1, '소속회사명2'])):
                appeared0 = False
                appeared99 = False
            val = df.loc[i, 'type2']
            if (val == '0'):
                if appeared0:
                    discard.append(i)
                else:
                    appeared0 = True
            elif (val == '50'):
                discard.append(i)
            elif (val == '99'):
                if appeared99:
                    discard.append(i)
                else:
                    appeared99 = True

        df.drop(discard, axis=0, inplace=True)

        # discard unwated columns and change the column names
        df = df[['소속회사명2', 'own', 'own2', 'type2', 'ownername']]
        df.columns = ['firmname', 'own', 'own2', 'type', 'ownername']

        # save the data in the after_discard folder
        if not os.path.exists('./data/after_discard'):
            os.makedirs('./data/after_discard')
        df.to_csv(f'./data/after_discard/{firmname}_{year}_after_discard.csv')

        return df

    def rel3_categorize(rel3):
        # import math
        import pandas as pd
        if (pd.isnull(rel3)):
            print("missing null value occured making type variable")
            return '-2'
        elif ((rel3 == '동일인') | (rel3 == '친족 합계') | (rel3 == '친족합계') | ('친족 합계' in rel3) | ('친족 합계' in rel3)):
            return '0'
        elif ('계열회사' in rel3):
            return '1'
        elif ('국내+해외' in rel3):
            return '1'
        elif ('해외계열' in rel3):
            return '1'
        elif ((rel3 == '기타주주') | (rel3 == '기타') | (rel3 == '기 타') | (rel3 == '동일인측이 아닌 최다주주') | (rel3 == '최다주주') | (rel3 == '동일인측이아닌 최다주주') | (
                rel3 == '동일인측이 아닌최다주주') | (rel3 == '동일인이 아닌 최다주주') | (rel3 == '동일인이아닌 최다주주') | (
                rel3 == '동일인이 아닌최다주주') | (rel3 == '동일인측이 아닌 최대주주') | (rel3 == '최대주주') | (rel3 == '동일인측이아닌 최대주주') | (
                rel3 == '동일인측이 아닌최대주주') | (rel3 == '동일인 측이 아닌 최다주주') | (rel3 == '동일인 측이 아닌 최대주주') | (rel3 == '동일인이 아닌 최대주주') | (rel3 == '동일인이아닌 최대주주') | (
                rel3 == '동일인이 아닌최대주주') | (rel3 == '동일인측이아닌최다주주')):
            return '99'
        elif (rel3 == '기타 동일인관련자'):
            return '-1'
        else:
            return '50'

    def rel3_categorize2(rel3):
        import pandas as pd
        if (pd.isnull(rel3)):
            print("missing null value occured making type2 variable")
            return '-2'
        elif ((rel3 == '동일인') | (rel3 == '친족 합계') | (rel3 == '친족합계') | ('친족 합계' in rel3) | ('친족 합계' in rel3) | (
                rel3 == '비영리법인') | (rel3 == '등기된 임원') | (rel3 == '등기된임원') | (rel3 == '자기주식') | (rel3 == '친족합계')):
            return '0'
        elif ('계열회사' in rel3):
            return '1'
        elif ('국내+해외' in rel3):
            return '1'
        elif ('해외계열' in rel3):
            return '1'
        elif ((rel3 == '기타주주') | (rel3 == '기타') | (rel3 == '기 타') | (rel3 == '동일인측이 아닌 최다주주') | (rel3 == '최다주주') | (rel3 == '동일인측이아닌 최다주주') | (
                rel3 == '동일인측이 아닌최다주주') | (rel3 == '동일인이 아닌 최다주주') | (rel3 == '동일인이아닌 최다주주') | (
                rel3 == '동일인이 아닌최다주주') | (rel3 == '동일인측이 아닌 최대주주') | (rel3 == '최대주주') | (rel3 == '동일인측이아닌 최대주주') | (
                rel3 == '동일인측이 아닌최대주주') | (rel3 == '동일인 측이 아닌 최다주주') | (rel3 == '동일인 측이 아닌 최대주주') | (rel3 == '동일인이 아닌 최대주주') | (rel3 == '동일인이아닌 최대주주') | (
                rel3 == '동일인이 아닌최대주주') | (rel3 == '동일인측이아닌최다주주')):
            return '99'
        elif (rel3 == '기타 동일인관련자'):
            return '-1'
        else:
            return '50'

    def getCBData(self, firmname: str, year: str):

        import os
        import pandas as pd

        print(f'Start parsing {firmname} {year} table...')
        df = self.parseCBTable(self.getRawCBData(firmname, year), firmname, year)

        checkData = df.groupby(['firmname']).sum('own2')

        # save the confirm data in the confirm folder
        if not os.path.exists('./data/confirm'):
            os.makedirs('./data/confirm')
        checkData.to_csv(f'./data/confirm/{firmname}_{year}_confirm.csv')

        print(f'Successfully saved {firmname} {year} data in \'./data/out/\'.\nCheck confirm data in \'./data/confirm/\'')

        mask = (abs((checkData - 1)['own2']) >= 0.001)
        print(f'Showing Erroneous Data in {firmname} {year}')
        # print(list(mask))
        pd.set_option("display.precision", 3)
        print(checkData.loc[mask, 'own2'])
        # save the output data in the out folder
        if not os.path.exists('./data/out'):
            os.makedirs('./data/out')
        df.to_csv(f'./data/out/{firmname}_{year}.csv')

    def getCBDataAll(self):

        for year in (2019, 2020):
            match = self.groupList[year-2019]
            for firmname in match['대표회사']:
                self.getCBData(firmname, str(year))

    def getCBDataof(self, year: int):

        match = self.groupList[year-2019]
        for firmname in match['대표회사']:
            self.getCBData(firmname, str(year))

    def getCBDataCont(self, start: str, year: int):
        match = self.groupList[year-2019]
        id = match['대표회사'].index(start)
        for firmname in match['대표회사'][id:]:
            self.getCBData(firmname, str(year))

    def saveGroupListData(self):

        if (len(self.groupList) > 0):
            import pandas as pd
            import os
            for i in range(len(self.groupList)):
                groupList = pd.DataFrame(self.groupList[i])
                if not os.path.exists('./data/group_list'):
                    os.makedirs('./data/group_list')
                groupList.to_csv(f'./data/group_list/{i+2019}_group_list.csv')

        else:
            print("No group list available. Set up group list data first.")



    def subtractOwner(df, firmname):
        mask = ((df['소속회사명2'] == firmname) & (df['동일인과의 관계3'] == '친족 합계')) | ((df['소속회사명2'] == firmname) & (df['동일인과의 관계3'] == '친족합계'))
        mask2 = (df['소속회사명2'] == firmname) & (df['동일인과의 관계3'] == '동일인')
        val = int(df.loc[mask, '합계 주식수'])
        val2 = int(df.loc[mask2, '합계 주식수'])
        df.loc[mask, '합계 주식수'] = val - val2


    def sumShares(df, firmname):
        import pandas as pd
        mask = (df['동일인과의 관계3'] != '총계') & (df['동일인과의 관계3'] != '총 계') & (df['동일인과의 관계3'] != '동일인측 합계') & (df['동일인과의 관계3'] != '친족 합계')
        sum = (df.loc[mask, ['소속회사명2', '합계 주식수']]).groupby('소속회사명2')['합계 주식수'].sum().reset_index()
        mask = ((df['소속회사명2'] == firmname) & ((df['동일인과의 관계3'] == '총계') | (df['동일인과의 관계3'] == '총 계')))
        df.loc[mask, '합계 주식수'] = float(sum[sum['소속회사명2'] == firmname]['합계 주식수'])


    def copyOrdinaryShares(df, firmname, name):
        mask = (df['소속회사명2'] == firmname) & (df['성명'] == name)
        df.loc[mask, '합계 주식수'] = df.loc[mask, '보통주 주식수']

    def copyOrdinaryShares2(df, firmname):
        mask = (df['소속회사명2'] == firmname) & (df['동일인과의 관계3'] == '총계')
        df.loc[mask, '합계 주식수'] = df.loc[mask, '보통주 주식수']

    def copySumShares(df, firmname, rel3_name):
        mask = (df['소속회사명2'] == firmname) & (df['동일인과의 관계3'] == '총계')
        mask2 = (df['소속회사명2'] == firmname) & (df['동일인과의 관계3'] == rel3_name)
        df.loc[mask, '합계 주식수'] = float(df.loc[mask2, '합계 주식수'])

    def save_pbDict(self):
        import pandas as pd
        pbDict_df = pd.DataFrame(self.pbDict)
        pbDict_df.to_csv('typos.csv')

    def save_groupList(self):
        import pandas as pd
        groupList_df = pd.DataFrame(self.groupList)
        groupList_df.to_csv('groupList.csv')

    def scrape_grpcode(self, year: int):
        """
        scrape KISLINE group code (grpcode) for <year> from KISLINE website(https://www.kisline.com)
        and update self.groupList
        :param year: a year for which updates groupList
        :return: None
        """
        if (self.w_to_d == {}):
            self.get_w_to_d_table()

        from selenium import webdriver
        from selenium.webdriver.support.ui import Select
        import pandas as pd

        grpcodeList = []

        driver = webdriver.Chrome('./chromedriver')
        driver.implicitly_wait(3)
        grsrch_url = 'https://www.kisline.com/cm/CM0100M00GE00.nice'
        username = 'wonbok'
        password = 'gkrtkrhk5034!'
        driver.get(grsrch_url)
        driver.find_element_by_class_name('btn_close_layer').click()

        driver.find_element_by_id('lgnuid').send_keys(username)
        driver.find_element_by_id('tmp_lgnupassword').click()
        driver.find_element_by_id('lgnupassword').send_keys(password)
        driver.find_element_by_class_name('btn_login').click()


        driver.switch_to.window(driver.window_handles[1])
        driver.close()
        driver.switch_to.window(driver.window_handles[0])

        driver.find_element_by_link_text('그룹').click()
        tables = []
        for group in self.groupList[year-2019]['기업집단']:
            if group == '엘지': kis_group = 'LG'
            elif group == '지에스': kis_group = 'GS'
            elif group == '에스케이': kis_group = 'SK'
            else: kis_group = group

            select = Select(driver.find_element_by_id('i_year'))
            select.select_by_value(str(year))
            driver.find_element_by_link_text('공시대상').click()
            inputElement = driver.find_element_by_id("srchk")
            inputElement.send_keys(kis_group)
            driver.find_element_by_link_text('조회').click()

            html = driver.page_source
            table = pd.read_html(html)[0].iloc[0]
            print(table)
            table['그룹코드'] = str(table['그룹코드'])

            # grpcode = table['그룹코드']
            # grpcode = driver.find_element_by_css_selector('#cont > div.tbl_type03 > table > tbody > tr:nth-child(1) > td:nth-child(1) > a').text
            # grp = driver.find_element_by_css_selector('#cont > div.tbl_type03 > table > tbody > tr:nth-child(1) > td:nth-child(2) > a').text
            grpcode_tf = table['그룹코드']
            table['기업집단'] = group

            for k, v in self.w_to_d.items():
                grpcode_tf = grpcode_tf.replace(k, v)
            # print(grp, grpcode, grpcode_tf)
            # grpcodeList.append(grpcode_tf)
            table['grpcode_cv'] = grpcode_tf
            table = table
            tables.append(table)
            driver.execute_script("window.history.go(-1)")

        driver.find_element_by_link_text('로그아웃').click()
        df1 = pd.DataFrame.from_dict(self.groupList[year-2019]).set_index('기업집단', drop=True)
        df2 = pd.concat(tables, axis=1).T.set_index('기업집단', drop=True)
        # print(df2.head())

        groupList = df1.join(df2)
        self.groupList[year-2019] = groupList
        self.saveGroupListData()




    def get_w_to_d_table(self):
        import os
        import pandas as pd
        df = pd.read_excel("2018 firmid list.xlsx", engine='openpyxl', sheet_name=2, index_col=0)
        df['숫자'] = df['숫자'].apply(str)
        w_to_d = df.to_dict()
        self.w_to_d = w_to_d['숫자']
        print(self.w_to_d)
        if not os.path.exists('./data'):
            os.makedirs('./data')
        pd.DataFrame.from_dict(self.w_to_d, orient='index')

    def get_firmid(self, year):

        if (self.w_to_d == {}):
            self.get_w_to_d_table()

        import pandas as pd
        from selenium import webdriver
        from selenium.webdriver.support.ui import Select
        from bs4 import BeautifulSoup
        import os
        import time

        groupdf2019 = pd.read_csv('./data/group_list/2019_group_list.csv')
        groupdf2020 = pd.read_csv('./data/group_list/2020_group_list.csv')
        groupList = [groupdf2019, groupdf2020]

        driver = webdriver.Chrome('./chromedriver')
        driver.implicitly_wait(3)
        url = 'https://www.kisline.com/gr/GR0100M00GE00.nice'
        username = 'wonbok'
        password = 'gkrtkrhk5034!'
        driver.get(url)
        time.sleep(1)
        driver.find_element_by_class_name('btn_close_layer').click()
        driver.find_element_by_id('lgnuid').send_keys(username)
        time.sleep(1)
        driver.find_element_by_id('tmp_lgnupassword').click()
        driver.find_element_by_id('lgnupassword').send_keys(password)
        time.sleep(1)
        driver.find_element_by_class_name('btn_login').click()
        time.sleep(1)
        driver.switch_to.window(driver.window_handles[1])
        driver.close()
        driver.switch_to.window(driver.window_handles[0])
        df = groupList[year-2019][40:]

        for i in df.index:
            firm_dict = {'firm':[], 'kiscode':[], 'kiscode_tf':[], 'business': []}
            time.sleep(1)
            driver.find_element_by_link_text('그룹').click()
            time.sleep(1)
            group = df.loc[i, '그룹명']
            inputElement = driver.find_element_by_id("srchk")
            inputElement.send_keys(group)
            time.sleep(1)
            driver.find_element_by_link_text('조회').click()
            time.sleep(1)
            if (group == '동원'):
                driver.find_element_by_css_selector('#cont > div.tbl_type03 > table > tbody > tr:nth-child(2) > td:nth-child(2) > a').click()
            else:
                driver.find_element_by_name('grpname').click()
            time.sleep(1)
            driver.find_element_by_link_text('계열사현황').click()
            time.sleep(1)
            if year == time.localtime().tm_year:
                continue
            else:
                select = Select(driver.find_element_by_id('i_year'))
                select.select_by_value(str(year))
                time.sleep(1)
                driver.find_element_by_id('slct').click()
                time.sleep(1)
            html = driver.page_source
            soup = BeautifulSoup(html, 'html.parser')
            # print(soup)
            target_links = soup.findAll("a", {"name": "overV"})
            # print(target_links)
            for link in target_links:
                # print(link)
                firm = link.text
                kiscode = link['data-kiscode']
                business = link['data-business']
                kiscode_tf = kiscode
                for k, v in self.w_to_d.items():
                    kiscode_tf = kiscode_tf.replace(k, v)
                firm_dict['firm'].append(firm)
                firm_dict['kiscode'].append(kiscode)
                firm_dict['kiscode_tf'].append(kiscode_tf)
                firm_dict['business'].append(business)
            # print(firm_dict)
            firm_df = pd.DataFrame.from_dict(firm_dict)

            if not os.path.exists(f'./data/kiscode{year}_3'):
                os.makedirs(f'./data/kiscode{year}_3')
            firm_df.to_csv(f'./data/kiscode{year}_3/kiscode_{group}_{year}.csv')
            firm_df.to_excel(f'./data/kiscode{year}_3/kiscode_{group}_{year}.xlsx')
            time.sleep(1)

    def concat_files(self, dir, ext):
        """
        concat all files in 'dir' location and save as 'concat.xlsx' and 'concat.csv' in dir
        :param dir:
        :return: None
        """

        import os
        import pandas as pd

        if dir[-1] == '/':
            dir = dir[:-1]
        file_list = os.listdir(dir)

        df_list = []
        for file in file_list:
            if file.endswith(f'.{ext}'):
                file = dir+'/'+file
                print(file)
                if ext == 'xlsx':
                    df_list.append(pd.read_excel(file, engine='openpyxl'))
                elif ext == 'csv':
                    df_list.append(pd.read_csv(file))
        df = pd.concat(df_list)
        df.replace('\(주\)', '', regex=True, inplace=True)
        df.replace('㈜', '', regex=True, inplace=True)
        df.to_csv(f'{dir}/concat.csv')
        df = df[['firm', 'kiscode', 'kiscode_tf', 'business']]
        df.to_excel(f'{dir}/concat.xlsx')
        df.to_csv(f'{dir}/concat.csv')

# %%
path = '../data/raw/opendart/corpCode/CORPCODE.zip'
path = os.path.normpath(path)
path.split(os.sep)
# Out:
# ['..', 'data', 'raw', 'opendart', 'corpCode', 'CORPCODE.zip']
